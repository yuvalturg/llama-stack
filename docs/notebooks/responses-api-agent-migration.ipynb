# %% [markdown]
# # Migrating from Agent objects to Responses in Llama Stack
#
# Llama Stack had a set of server APIs for creating and managing the components of an agent including endpoints for grouping tools, making an agent that uses those groups of tools, making a session for that agent, and making a turn for that session.  However, these server APIs are deprecated in Llama Stack 0.3.0.  The functionality in those server APIs continue to exist the client APIs, but they are relatively limited and are not expected to undergo substantial improvement so they are not recommended for new development.  Instead, the recommended replacement for those APIs is the OpenAI-compatible Responses API which provides an all-in-one API for doing agentic reasoning.
#
# To learn more about the Responses API and why you might want to use it see [Your agent, your rules: A deep dive into the Responses API with Llama Stack](https://developers.redhat.com/articles/2025/08/20/your-agent-your-rules-deep-dive-responses-api-llama-stack) from Red Hat and/or [Why we built the Responses API](https://developers.openai.com/blog/responses-api/).  This notebook is more specifically focused on the following topic:
#
# > *What do I do if I have an existing system implemented using the old Llama Stack agent APIs and I want to use the Llama Stack Responses API instead?*
#
# To that end, we present the following:
#
# - *Getting Started*: Instructions for setting up, configuring, creating a client, and testing it out.
# - *Legacy Agent API Example*: Code that creates and runs an agent using the Llama Stack client Agent APIs.
# - *Equivalent Responses API Example*: Code that does the same thing by calling the Responses API to show how you would rewrite the first example to use Responses API.  That is probably the best approach for most users who are using the old APIs and want to move to the new one.  That code is significantly simpler and more elegant than the equivalent code using the old APIs.
# - *Emulating the Legacy Agent API*: Code that provides a wrapper around the Responses API that emulates the old agent APIs along with code that mirrors the original example using that emulation.  Note that the emulation is a partial/incomplete emulation of the old APIs that is just powerful enough to implement the simple example.  It is meant to be a starting point for you to emulate those parts of the old agent APIs that are essential for your application.
# - *Adopting a simpler agent class*: A simpler wrapper that is less consistent with the old APIs but might be an easier starting point if complete compatibility with the old APIs are less essential.
# - *Human-in-the-loop tool approval*: Example of how to have an agent that checks with the user for approval before invoking a tool.
# - *Model safety*: Example of how safety models are used with both the old agent APIs and the new Responses API.
# - *ReAct agents*: Example of using the ReAct agent construct in the Llama Stack Python client library and how to accomplish something similar using the Responses API.
# - *Authored multi-step agentic flows*: Example of how to break a challenging agentic reasoning task into multiple steps to improve accuracy on the task.
# - *Multi-process architectures*: Thoughts on how to migrate applications that run different aspects of the old APIs in different processes (e.g., one process to make agents and another to consume them).
#
# The development of this notebook was assisted by Google Gemini and Cursor using Claude 4 Sonnet.

# %% [markdown]
# ## Getting Started
#
# Before getting started, follow the following steps.
#
# First install Llama Stack and all of the other dependencies for this notebook.
# One way to do that is:
#
# - First install Python 3.12 or later (do not try this with older versions of Python: it will not work).
# - Then make a Python virtual environment and start using it.
# - Then install Llama Stack.  For example, to install the latest from the main branch run:
#
# ```
# pip install git+ssh://git@github.com/llamastack/llama-stack.git
# pip install git+ssh://git@github.com/llamastack/llama-stack-client.git
# ```
#
# Once everything is installed, run the Llama Stack server:
#
# ```
# llama stack run starter
# ```
#
# Note that you can also use `uv` for all of these commands, which is a very popular tool for managing Python configurations.
#
# Also run the National Parks Service Model Context Protocol (MCP) server as described in [README_NPS.md](https://github.com/The-AI-Alliance/llama-stack-examples/blob/main/notebooks/01-responses/README_NPS.md).  Download it from that location and then run it using:
#
# ```
# python nps_mcp_server.py --transport sse --port 3005
# ```
#
# Alternatively, you can use this notebook with some other MCP server, but then you will need to change the example query and the server details to match

# %% [markdown]
# This demo uses models from OpenAI.  They will only work if you have OPENAI_API_KEY set in your environment to a [valid OpenAI API key](https://help.openai.com/en/articles/4936850-where-do-i-find-my-openai-api-key).  If you don't have such a key, you can try using a different model, although you might not get good results from smaller models since some of the examples here are relatively challenging.

# %%
# Using gpt-4o for this demo, but feel free to try another model.
LLAMA_STACK_MODEL_ID = "openai/gpt-4o"
LLAMA_STACK_URL = "http://localhost:8321"

# %% [markdown]
# Replace these with other values if you are using a different MCP server:

# %%
NPS_MCP_URL = "http://localhost:3005/sse/"
NPS_EXAMPLE_PROMPT = "Tell me about some parks in Rhode Island, and let me know if there are any upcoming events at them."
NPS_EXAMPLE_FOLLOWUP_PROMPT = "Which of these is happening the soonest?"

NPS_INSTRUCTIONS = "You are a helpful assistant that can answer questions about the National Parks Service."

# The NPS MCP server does not require an access token, but some MCP servers do.
# We are sending it a dummy token here to show how to send the access token to the MCP server.
NPS_ACCESS_TOKEN = "frog"

# %% [markdown]
# Next we instantiate the client:

# %%
from llama_stack_client import LlamaStackClient

client = LlamaStackClient(base_url="http://localhost:8321")

# %% [markdown]
# Then we test to see if it is working:

# %%
chat_completion_response = client.chat.completions.create(
    model=LLAMA_STACK_MODEL_ID,
    messages=[{"role": "user", "content": "What is the capital of France?"}]
)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/chat/completions "HTTP/1.1 200 OK"

# %%
import json
from datetime import date

def pretty_print(obj) -> None:
    """
    Recursively prints an object's __dict__ in a nicely formatted JSON.
    Handles nested objects and lists of objects.
    """
    def recursive_serializer(o):
        if hasattr(o, '__dict__'):
            return o.__dict__
        # Handle types that are not directly JSON serializable
        if isinstance(o, date):
            return o.isoformat()
        # For other types, raise a TypeError to let the default handler fail.
        raise TypeError(f"Object of type {o.__class__.__name__} is not JSON serializable")

    # Determine what to serialize
    data_to_serialize = obj.__dict__ if hasattr(obj, "__dict__") else obj

    print(json.dumps(
        data_to_serialize,
        indent=2,
        default=recursive_serializer
    ))


pretty_print(chat_completion_response)
# Out:
# {
#   "id": "chatcmpl-ClL2a5LBpjcN3zcKOABMKDxmfIgCE",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "The capital of France is Paris.",
#         "name": null,
#         "role": "assistant",
#         "tool_calls": null
#       },
#       "logprobs": null
#     }
#   ],
#   "created": 1765398332,
#   "model": "openai/gpt-4o",
#   "object": "chat.completion",
#   "usage": {
#     "completion_tokens": 7,
#     "prompt_tokens": 14,
#     "total_tokens": 21,
#     "completion_tokens_details": {
#       "reasoning_tokens": 0
#     },
#     "prompt_tokens_details": {
#       "cached_tokens": 0
#     }
#   }
# }

# %% [markdown]
# ## Legacy Agent API Example
#
# Here is a simple example for how to use the Llama Stack Agent API.  We don't recommend this approach because the primary strategic focus for Llama Stack is OpenAI-compatible APIs since those reflect a de facto industry "standard".  We're showing that API here for context to motivate the alternative approaches in later sections.

# %% [markdown]
# Here (commented out) is an example of how an Agent was intended to be instantiated in older versions of Llama Stack as per some [old documentation for MCP with Agent in Llama Stack](https://llamastack.github.io/v0.2.22/building_applications/tools.html#model-context-protocol-mcp):

# %%
# from llama_stack_client import Agent
# import uuid

# client.toolgroups.register(
#     toolgroup_id="mcp::nps",
#     provider_id="model-context-protocol",
#     mcp_endpoint=URL(uri=NPS_MCP_URL),
# )

# agent = Agent(
#     model=LLAMA_STACK_MODEL_ID,
#     instructions=NPS_INSTRUCTIONS,
#     client=client,
#     tools=["mcp::nps"],
#     extra_headers={
#         "X-LlamaStack-Provider-Data": json.dumps(
#             {
#                 "mcp_headers": {
#                     NPS_MCP_URL: {
#                         "Authorization": f"Bearer {NPS_ACCESS_TOKEN}",
#                     },
#                 },
#             }
#         ),
#     },
# )

# %% [markdown]
# The approach above no longer works, but you can now specify MCP tools directly in the Agent object in the Python client for similar behavior:

# %%
from llama_stack_client import Agent
import uuid

agent = Agent(
    model=LLAMA_STACK_MODEL_ID,
    instructions=NPS_INSTRUCTIONS,
    client=client,
    tools=[{
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "NPS",
            "authorization": NPS_ACCESS_TOKEN,
        }])

# %%
# Generate a unique session ID for the example.
# This is not required, but it is useful to have if you want to create multiple sessions without restarting Llama Stack.
session_id = agent.create_session(f"nps_session-{uuid.uuid4().hex}")

agent_response1 = agent.create_turn(
    messages=[{"role": "user", "content": NPS_EXAMPLE_PROMPT}],
    session_id=session_id,
    stream=False,
)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/conversations "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"

# %%
pretty_print(agent_response1)
# Out:
# {
#   "id": "resp_8ab5470d-b492-4875-ac6b-3573e7949ea1",
#   "created_at": 1765398333,
#   "model": "openai/gpt-4o",
#   "output": [
#     {
#       "id": "mcp_list_78adb18a-9776-4195-a874-1858a4a54a3f",
#       "server_label": "NPS",
#       "tools": [
#         {
#           "input_schema": {
#             "properties": {
#               "state_code": {
#                 "anyOf": [
#                   {
#                     "type": "string"
#                   },
#                   {
#                     "type": "null"
#                   }
#                 ],
#                 "default": null,
#                 "title": "State Code"
#               },
#               "park_code": {
#                 "anyOf": [
#                   {
#                     "type": "string"
#                   },
#                   {
#                     "type": "null"
#                   }
#                 ],
#                 "default": null,
#                 "title": "Park Code"
#               },
#               "query": {
#                 "anyOf": [
#                   {
#                     "type": "string"
#                   },
#                   {
#                     "type": "null"
#                   }
#                 ],
#                 "default": null,
#                 "title": "Query"
#               },
#               "limit": {
#                 "default": 10,
#                 "title": "Limit",
#                 "type": "integer"
#               }
#             },
#             "type": "object"
#           },
#           "name": "search_parks",
#           "description": "Search for national parks by state, park code, or query string.\n\nArgs:\n    state_code: Two-letter state code (e.g., 'CA', 'NY')\n    park_code: Four-letter park code (e.g., 'yell', 'acad')\n    query: Search query for park names or descriptions\n    limit: Maximum number of results to return (default: 10)\n\nReturns:\n    JSON string with park information including name, description, website, and location"
#         },
#         {
#           "input_schema": {
#             "properties": {
#               "park_code": {
#                 "title": "Park Code",
#                 "type": "string"
#               }
#             },
#             "required": [
#               "park_code"
#             ],
#             "type": "object"
#           },
#           "name": "get_park_alerts",
#           "description": "Get current alerts for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n\nReturns:\n    JSON string with current alerts for the park"
#         },
#         {
#           "input_schema": {
#             "properties": {
#               "park_code": {
#                 "title": "Park Code",
#                 "type": "string"
#               },
#               "limit": {
#                 "default": 10,
#                 "title": "Limit",
#                 "type": "integer"
#               }
#             },
#             "required": [
#               "park_code"
#             ],
#             "type": "object"
#           },
#           "name": "get_park_campgrounds",
#           "description": "Get campground information for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of campgrounds to return (default: 10)\n\nReturns:\n    JSON string with campground information including location, amenities, and fees"
#         },
#         {
#           "input_schema": {
#             "properties": {
#               "park_code": {
#                 "title": "Park Code",
#                 "type": "string"
#               },
#               "limit": {
#                 "default": 10,
#                 "title": "Limit",
#                 "type": "integer"
#               }
#             },
#             "required": [
#               "park_code"
#             ],
#             "type": "object"
#           },
#           "name": "get_park_events",
#           "description": "Get upcoming events for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of events to return (default: 10)\n\nReturns:\n    JSON string with event information including date, time, fee, and description"
#         },
#         {
#           "input_schema": {
#             "properties": {
#               "park_code": {
#                 "title": "Park Code",
#                 "type": "string"
#               },
#               "limit": {
#                 "default": 10,
#                 "title": "Limit",
#                 "type": "integer"
#               }
#             },
#             "required": [
#               "park_code"
#             ],
#             "type": "object"
#           },
#           "name": "get_visitor_centers",
#           "description": "Get visitor center information for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of visitor centers to return (default: 10)\n\nReturns:\n    JSON string with visitor center information including location, contact, and operating hours"
#         }
#       ],
#       "type": "mcp_list_tools"
#     },
#     {
#       "id": "fc_92bc14cb-6b45-409a-83e4-412334a8ada2",
#       "arguments": "{\"state_code\":\"RI\"}",
#       "name": "search_parks",
#       "server_label": "NPS",
#       "error": null,
#       "output": "{\n  \"total\": \"4\",\n  \"parks\": [\n    {\n      \"name\": \"Blackstone River Valley National Historical Park\",\n      \"code\": \"blrv\",\n      \"description\": \"The Blackstone River powered America's entry into the Age of Industry. The success of Samuel Slater's cotton spinning mill in Pawtucket, RI touched off a chain reaction that changed how people worked and where they lived. Learn how this revolution transformed the landscape of the Blackstone Valley and the United States. The Visitor Center at Old Slater Mill is closed for the winter season.\",\n      \"website\": \"https://www.nps.gov/blrv/index.htm\",\n      \"states\": \"RI,MA\",\n      \"designation\": \"National Historical Park\",\n      \"latitude\": \"41.8775792792\",\n      \"longitude\": \"-71.382433945\"\n    },\n    {\n      \"name\": \"Roger Williams National Memorial\",\n      \"code\": \"rowi\",\n      \"description\": \"\\\"I acknowledge that to molest any person, Jew or Gentile, for either professing doctrine, or practicing worship meerly religious or spiritual, is to persecute him, and such a person (whether his doctrine or practice be true or false) suffers persecution for conscience.\\\" -Roger Williams, 1644 Banished by the English and saved by the First Peoples, Roger Williams founded Providence here in 1636.\",\n      \"website\": \"https://www.nps.gov/rowi/index.htm\",\n      \"states\": \"RI\",\n      \"designation\": \"National Memorial\",\n      \"latitude\": \"41.8298955\",\n      \"longitude\": \"-71.41056665\"\n    },\n    {\n      \"name\": \"Touro Synagogue National Historic Site\",\n      \"code\": \"tosy\",\n      \"description\": \"Touro Synagogue, a building of exquisite beauty and design, steeped in history and ideals, and one of the most historically significant Jewish buildings in America, was designated a National Historic Site in 1946. Dedicated in 1763, it still serves an active congregation and each year greets over 30,000 visitors who come to see the magnificent interior and hear its remarkable story.\",\n      \"website\": \"https://www.nps.gov/tosy/index.htm\",\n      \"states\": \"RI\",\n      \"designation\": \"National Historic Site\",\n      \"latitude\": \"41.4893\",\n      \"longitude\": \"-71.3121\"\n    },\n    {\n      \"name\": \"Washington-Rochambeau Revolutionary Route National Historic Trail\",\n      \"code\": \"waro\",\n      \"description\": \"\\u201cOf the happiness I have enjoyed in our private friendship. The remembrance of which will be one of the most pleasing Circumstances of my life.\\u201d\\u2013 Comte de Rochambeau on his relationship with George Washington\",\n      \"website\": \"https://www.nps.gov/waro/index.htm\",\n      \"states\": \"MA,RI,CT,NY,NJ,PA,DE,MD,VA,DC\",\n      \"designation\": \"National Historic Trail\",\n      \"latitude\": \"40.0958204557\",\n      \"longitude\": \"-74.8563515109\"\n    }\n  ]\n}",
#       "type": "mcp_call"
#     },
#     {
#       "id": "fc_cf7693d7-8958-4d15-91ea-faacd1abdaf9",
#       "arguments": "{\"park_code\": \"blrv\"}",
#       "name": "get_park_events",
#       "server_label": "NPS",
#       "error": null,
#       "output": "{\n  \"parkCode\": \"BLRV\",\n  \"totalEvents\": 6,\n  \"events\": [\n    {\n      \"title\": \"Blackstone Canal Hike Series\",\n      \"description\": \"<p class=\\\"\\\">Join us for hikes on Saturday mornings in January at 10:30 AM. Hikes will depart from various locations along the historic Blackstone Canal on 1/3, 1/10, 1/17, and 1/24.</p>\\n<p class=\\\"\\\">All hikes are free. This series is presented in partnership with MA DCR.</p>\\n<h4 class=\\\"\\\">January 3: Blackstone River State Park</h4>\\n<p class=\\\"\\\">Meet at the Kelly House Museum, 1075 Lower River Road, Lincoln, RI</p>\\n<h4 class=\\\"\\\">January 10: Millville Lock</h4>\\n<p class=\\\"\\\">Meet at Blackstone River Greenway Parking Lot, Corner of Central Street and Hope Street, Millville, MA</p>\\n<h4 class=\\\"\\\">January 17: The Old Stanley Woolen Mills</h4>\\n<p class=\\\"\\\">Meet at Trailhead at 9 Cross Street, Uxbridge, MA</p>\\n<h4 class=\\\"\\\">January 24: Goat Hill Lock</h4>\\n<p class=\\\"\\\">Meet at River Bend Farm Visitor Center, 287 Oak Street, Uxbridge, MA</p>\\n<p class=\\\"\\\"><em class=\\\"\\\">Please note: these programs are subject to cancelation because of inclement weather. Check the park\\u2019s website and Facebook page for the latest information on whether programs have been canceled.</em></p>\",\n      \"location\": \"Meet at the Kelly House Museum, 1075 Lower River Road, Lincoln, RI\",\n      \"dateStart\": \"\",\n      \"dateEnd\": \"\",\n      \"timeStart\": \"\",\n      \"timeEnd\": \"\",\n      \"feeInfo\": \"\",\n      \"isRecurring\": false,\n      \"parkCode\": \"\"\n    },\n    {\n      \"title\": \"Blackstone Canal Hike Series\",\n      \"description\": \"<p class=\\\"\\\">Join us for hikes on Saturday mornings in January at 10:30 AM. Hikes will depart from various locations along the historic Blackstone Canal on 1/3, 1/10, 1/17, and 1/24.</p>\\n<p>\\u00a0</p>\\n<p class=\\\"\\\">All hikes are free. This series is presented in partnership with MA DCR.</p>\\n<h4>January 10: Millville Lock</h4>\\n<p>Meet at Blackstone River Greenway Parking Lot, Corner of Central Street and Hope Street, Millville, MA</p>\\n<p>\\u00a0</p>\\n<h4 class=\\\"\\\">January 17: The Old Stanley Woolen Mills</h4>\\n<p>\\u00a0</p>\\n<p class=\\\"\\\">Meet at Trailhead at 9 Cross Street, Uxbridge, MA</p>\\n<p>\\u00a0</p>\\n<h4 class=\\\"\\\">January 24: Goat Hill Lock</h4>\\n<p>\\u00a0</p>\\n<p class=\\\"\\\">Meet at River Bend Farm Visitor Center, 287 Oak Street, Uxbridge, MA</p>\\n<p>\\u00a0</p>\\n<p class=\\\"\\\"><em class=\\\"\\\">Please note: these programs are subject to cancelation because of inclement weather. Check the park\\u2019s website and Facebook page for the latest information on whether programs have been canceled.</em></p>\",\n      \"location\": \"Meet at Blackstone River Greenway Parking Lot, Corner of Central Street and Hope Street, Millville, MA\",\n      \"dateStart\": \"\",\n      \"dateEnd\": \"\",\n      \"timeStart\": \"\",\n      \"timeEnd\": \"\",\n      \"feeInfo\": \"\",\n      \"isRecurring\": false,\n      \"parkCode\": \"\"\n    },\n    {\n      \"title\": \"Revolutionary War Pension Files Transcription Event\",\n      \"description\": \"<p>In celebration of the 250th anniversary of American independence, the National Archives and the National Park Service are collaborating on a special project to transcribe Revolutionary War Pension Files of more than 80,000 of America's first veterans and their windows, containing more than 2 million documents. These records may contain valuable details about Revolutionary War veterans and their families, such as rank, unit, period of service, age, residence, date and place of marriage, and date and place of death of spouse. You may find copies of marriage or other family records, information pertaining to military activities or details about soldier's lives, along with letters, diaries, or family trees within these records. Become a citizen archivist and unlo ...
#       "type": "mcp_call"
#     },
#     {
#       "id": "fc_ccfd3edf-930b-454c-9f78-230f5451c277",
#       "arguments": "{\"park_code\": \"rowi\"}",
#       "name": "get_park_events",
#       "server_label": "NPS",
#       "error": null,
#       "output": "{\n  \"parkCode\": \"ROWI\",\n  \"totalEvents\": 1,\n  \"events\": [\n    {\n      \"title\": \"Visitor Center Open\",\n      \"description\": \"<p>Explore the life and legacy of Roger Williams. Park Rangers and volunteers are standing by. While you're here, watch our 5 minute film, read our exhibits, browse the bookstore, and use our facilites.</p>\",\n      \"location\": \"\",\n      \"dateStart\": \"\",\n      \"dateEnd\": \"\",\n      \"timeStart\": \"\",\n      \"timeEnd\": \"\",\n      \"feeInfo\": \"\",\n      \"isRecurring\": false,\n      \"parkCode\": \"\"\n    }\n  ]\n}",
#       "type": "mcp_call"
#     },
#     {
#       "id": "fc_7ffc4e25-a69c-41c0-bbd9-c1558a7844f7",
#       "arguments": "{\"park_code\": \"tosy\"}",
#       "name": "get_park_events",
#       "server_label": "NPS",
#       "error": null,
#       "output": "{\"parkCode\": \"TOSY\", \"message\": \"No upcoming events found for this park\"}",
#       "type": "mcp_call"
#     },
#     {
#       "id": "fc_d4c53798-35ab-4208-81c9-1f9a698c3754",
#       "arguments": "{\"park_code\": \"waro\"}",
#       "name": "get_park_events",
#       "server_label": "NPS",
#       "error": null,
#       "output": "{\"parkCode\": \"WARO\", \"message\": \"No upcoming events found for this park\"}",
#       "type": "mcp_call"
#     },
#     {
#       "content": [
#         {
#           "text": "Here are some parks in Rhode Island and their upcoming events:\n\n1. **Blackstone River Valley National Historical Park**\n   - **Description**: This park commemorates the Blackstone River's role in powering America's entry into the Age of Industry. It highlights the significance of Samuel Slater's cotton spinning mill in Pawtucket, RI.\n   - **Website**: [Blackstone River Valley National Historical Park](https://www.nps.gov/blrv/index.htm)\n   - **Upcoming Events**:\n     - **Blackstone Canal Hike Series**: Join hikes on Saturday mornings in January at 10:30 AM. The hikes will take place at different locations along the historic Blackstone Canal. All hikes are free.\n     - **Revolutionary War Pension Files Transcription Event**: Participate in a special project to transcribe Revolutionary War Pension Files. Events are being held at the Upton Community Center on January 14, 2026, and the Sutton Senior Center on January 28, 2026.\n\n2. **Roger Williams National Memorial**\n   - **Description**: This memorial celebrates Roger Williams, who founded Providence in 1636 after being banished by the English.\n   - **Website**: [Roger Williams National Memorial](https://www.nps.gov/rowi/index.htm)\n   - **Upcoming Event**:\n     - **Visitor Center Open**: Explore the life and legacy of Roger Williams with park rangers and volunteers. Enjoy the exhibits, a 5-minute film, and the bookstore.\n\n3. **Touro Synagogue National Historic Site**\n   - **Description**: Touro Synagogue is a significant Jewish building in America, serving an active congregation since 1763.\n   - **Website**: [Touro Synagogue National Historic Site](https://www.nps.gov/tosy/index.htm)\n   - **Upcoming Events**: No upcoming events found at this park.\n\n4. **Washington-Rochambeau Revolutionary Route National Historic Trail**\n   - **Description**: This trail traces the route taken by American and French forces during the Revolutionary War.\n   - **Website**: [Washington-Rochambeau Revolutionary Route National Historic Trail](https://www.nps.gov/waro/index.htm)\n   - **Upcoming Events**: No upcoming events found at this park.\n\nFeel free to explore the links for more detailed information and reach out if you have questions about specific events.",
#           "annotations": [],
#           "type": "output_text"
#         }
#       ],
#       "role": "assistant",
#       "id": "msg_0b8fa490-914e-4b87-aa67-04b88bc09de2",
#       "status": "completed",
#       "type": "message"
#     }
#   ],
#   "status": "completed",
#   "error": null,
#   "instructions": "You are a helpful assistant that can answer questions about the National Parks Service.",
#   "max_tool_calls": null,
#   "object": "response",
#   "parallel_tool_calls": true,
#   "previous_response_id": null,
#   "prompt": null,
#   "temperature": null,
#   "text": {
#     "format": {
#       "description": null,
#       "name": null,
#       "schema_": null,
#       "strict": null,
#       "type": "text"
#     }
#   },
#   "tools": [
#     {
#       "server_label": "NPS",
#       "allowed_tools": null,
#       "type": "mcp"
#     }
#   ],
#   "top_p": null,
#   "truncation": null,
#   "usage": {
#     "input_tokens": 5514,
#     "output_tokens": 594,
#     "total_tokens": 6108,
#     "input_tokens_details": {
#       "cached_tokens": 1280
#     },
#     "output_tokens_details": {
#       "reasoning_tokens": 0
#     }
#   }
# }

# %% [markdown]
# Next we ask a follow-on question using the same session ID so that it will use the context of the existing conversation to understand the question.

# %%
agent_response2 = agent.create_turn(
    messages=[{"role": "user", "content": NPS_EXAMPLE_FOLLOWUP_PROMPT}], # "Which of these is happening the soonest?"
    session_id=session_id,
    stream=False,
)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"

# %%
pretty_print(agent_response2)
# Out:
# {
#   "id": "resp_ed367b69-15c0-4094-8f8e-f5e701dff415",
#   "created_at": 1765398347,
#   "model": "openai/gpt-4o",
#   "output": [
#     {
#       "id": "mcp_list_7ada6d2d-8588-4c60-98bb-9ec47777c863",
#       "server_label": "NPS",
#       "tools": [
#         {
#           "input_schema": {
#             "properties": {
#               "state_code": {
#                 "anyOf": [
#                   {
#                     "type": "string"
#                   },
#                   {
#                     "type": "null"
#                   }
#                 ],
#                 "default": null,
#                 "title": "State Code"
#               },
#               "park_code": {
#                 "anyOf": [
#                   {
#                     "type": "string"
#                   },
#                   {
#                     "type": "null"
#                   }
#                 ],
#                 "default": null,
#                 "title": "Park Code"
#               },
#               "query": {
#                 "anyOf": [
#                   {
#                     "type": "string"
#                   },
#                   {
#                     "type": "null"
#                   }
#                 ],
#                 "default": null,
#                 "title": "Query"
#               },
#               "limit": {
#                 "default": 10,
#                 "title": "Limit",
#                 "type": "integer"
#               }
#             },
#             "type": "object"
#           },
#           "name": "search_parks",
#           "description": "Search for national parks by state, park code, or query string.\n\nArgs:\n    state_code: Two-letter state code (e.g., 'CA', 'NY')\n    park_code: Four-letter park code (e.g., 'yell', 'acad')\n    query: Search query for park names or descriptions\n    limit: Maximum number of results to return (default: 10)\n\nReturns:\n    JSON string with park information including name, description, website, and location"
#         },
#         {
#           "input_schema": {
#             "properties": {
#               "park_code": {
#                 "title": "Park Code",
#                 "type": "string"
#               }
#             },
#             "required": [
#               "park_code"
#             ],
#             "type": "object"
#           },
#           "name": "get_park_alerts",
#           "description": "Get current alerts for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n\nReturns:\n    JSON string with current alerts for the park"
#         },
#         {
#           "input_schema": {
#             "properties": {
#               "park_code": {
#                 "title": "Park Code",
#                 "type": "string"
#               },
#               "limit": {
#                 "default": 10,
#                 "title": "Limit",
#                 "type": "integer"
#               }
#             },
#             "required": [
#               "park_code"
#             ],
#             "type": "object"
#           },
#           "name": "get_park_campgrounds",
#           "description": "Get campground information for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of campgrounds to return (default: 10)\n\nReturns:\n    JSON string with campground information including location, amenities, and fees"
#         },
#         {
#           "input_schema": {
#             "properties": {
#               "park_code": {
#                 "title": "Park Code",
#                 "type": "string"
#               },
#               "limit": {
#                 "default": 10,
#                 "title": "Limit",
#                 "type": "integer"
#               }
#             },
#             "required": [
#               "park_code"
#             ],
#             "type": "object"
#           },
#           "name": "get_park_events",
#           "description": "Get upcoming events for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of events to return (default: 10)\n\nReturns:\n    JSON string with event information including date, time, fee, and description"
#         },
#         {
#           "input_schema": {
#             "properties": {
#               "park_code": {
#                 "title": "Park Code",
#                 "type": "string"
#               },
#               "limit": {
#                 "default": 10,
#                 "title": "Limit",
#                 "type": "integer"
#               }
#             },
#             "required": [
#               "park_code"
#             ],
#             "type": "object"
#           },
#           "name": "get_visitor_centers",
#           "description": "Get visitor center information for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of visitor centers to return (default: 10)\n\nReturns:\n    JSON string with visitor center information including location, contact, and operating hours"
#         }
#       ],
#       "type": "mcp_list_tools"
#     },
#     {
#       "content": [
#         {
#           "text": "The events happening the soonest are the **Blackstone Canal Hike Series** at the Blackstone River Valley National Historical Park, which occur on Saturday mornings in January at 10:30 AM. The specific dates for these hikes are January 3rd, January 10th, January 17th, and January 24th, making January 3rd the earliest event. ",
#           "annotations": [],
#           "type": "output_text"
#         }
#       ],
#       "role": "assistant",
#       "id": "msg_0661df9a-854c-41d4-9596-8c90c441a6d3",
#       "status": "completed",
#       "type": "message"
#     }
#   ],
#   "status": "completed",
#   "error": null,
#   "instructions": "You are a helpful assistant that can answer questions about the National Parks Service.",
#   "max_tool_calls": null,
#   "object": "response",
#   "parallel_tool_calls": true,
#   "previous_response_id": null,
#   "prompt": null,
#   "temperature": null,
#   "text": {
#     "format": {
#       "description": null,
#       "name": null,
#       "schema_": null,
#       "strict": null,
#       "type": "text"
#     }
#   },
#   "tools": [
#     {
#       "server_label": "NPS",
#       "allowed_tools": null,
#       "type": "mcp"
#     }
#   ],
#   "top_p": null,
#   "truncation": null,
#   "usage": {
#     "input_tokens": 4163,
#     "output_tokens": 79,
#     "total_tokens": 4242,
#     "input_tokens_details": {
#       "cached_tokens": 4096
#     },
#     "output_tokens_details": {
#       "reasoning_tokens": 0
#     }
#   }
# }

# %% [markdown]
# As you can see this approach still works and can be a viable substitute for the approach commented out above.  It is a bit simpler and more elegant since you no longer need to separately register tool groups and then use them in your agent definition.

# %% [markdown]
# ## Equivalent Responses API Example

# %% [markdown]
# Here is some code using the Responses API that is roughly equivalent to the Agent example above.  As you can see, it no longer has separate calls for:
#
# - Registering tools
# - Creating an agent
# - Creating a session
# - Issuing a query for that session
#
# The Responses API takes the list of tools as an argument so there is no need to pre-register the tools.  It does not make a persistent agent object but it does make a session object implicitly within the call -- you can see how that is used in the second call, in which `previous_response_id=responses_api_response1.id` is set to indicate that the second call is a continuation of the first.

# %%
responses_api_response1 = client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input=NPS_EXAMPLE_PROMPT,
    instructions=NPS_INSTRUCTIONS,
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "NPS",
            "requires_approval": False,
            "authorization": NPS_ACCESS_TOKEN,
        }
    ]
)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"

# %%
print(responses_api_response1.output_text)
# Out:
# Here are some national parks in Rhode Island, along with information on their upcoming events:
#
# ### Blackstone River Valley National Historical Park
# - **Description:** The Blackstone River powered America's entry into the Age of Industry, starting with Samuel Slater's cotton spinning mill in Pawtucket, RI.
# - **Website:** [Blackstone River Valley NHP](https://www.nps.gov/blrv/index.htm)
#
# #### Upcoming Events:
# 1. **Blackstone Canal Hike Series**
#    - Join hikes on Saturday mornings in January at 10:30 AM. Locations include the Kelly House Museum in Lincoln, RI, Millville Lock in Millville, MA, and more. Events are free but weather-dependent.
#    - **Location:** Various sites along the Blackstone Canal.
#
# 2. **Revolutionary War Pension Files Transcription Event**
#    - On January 14, 2026, from 6-8 PM, join a transcription event at the Upton Community Center in Massachusetts, to help transcribe Revolutionary War Pension Files.
#    - **Note:** Bring a laptop or tablet. Email [UptonMAHistoricalSociety@gmail.com](mailto:UptonMAHistoricalSociety@gmail.com) for participation.
#
# ### Roger Williams National Memorial
# - **Description:** Learn about religious freedom and Providence’s founder, Roger Williams.
# - **Website:** [Roger Williams National Memorial](https://www.nps.gov/rowi/index.htm)
#
# #### Upcoming Event:
# - **Visitor Center Open**
#   - Explore the life and legacy of Roger Williams with park rangers, exhibits, a bookstore, and a short film.
#
# ### Touro Synagogue National Historic Site
# - **Description:** A historic Jewish building recognized for its beauty and history, still active with an annual visitor count exceeding 30,000.
# - **Website:** [Touro Synagogue NHS](https://www.nps.gov/tosy/index.htm)
#
# #### Upcoming Events:
# - No upcoming events are currently found for this park.
#
# ### Washington-Rochambeau Revolutionary Route National Historic Trail
# - **Description:** A historic trail emphasizing the friendship between George Washington and Comte de Rochambeau.
# - **Website:** [Washington-Rochambeau NHT](https://www.nps.gov/waro/index.htm)
#
# #### Upcoming Events:
# - No upcoming events are currently found for this park.
#
# Feel free to check the park websites for the most up-to-date event details and potential weather-related changes.

# %% [markdown]
# Below is some utility code to print some of the highlights of a Responses object so you can see what happened under the hood.  You could also get this information from running pretty_print on the response object, but it is a pretty big object, so that winds up being a lot to read through.

# %%
def print_response(response):
    print(f"ID: {response.id}")
    print(f"Status: {response.status}")
    print(f"Model: {response.model}")
    print(f"Created at: {response.created_at}")
    print(f"Output items: {len(response.output)}")
    
    for i, output_item in enumerate(response.output):
        if len(response.output) > 1:
            print(f"\n--- Output Item {i+1} ---")
        print(f"Output type: {output_item.type}")
        
        if output_item.type in ("text", "message"):
            print(f"Response content: {output_item.content[0].text}")
        elif output_item.type == "file_search_call":
            print(f"  Tool Call ID: {output_item.id}")
            print(f"  Tool Status: {output_item.status}")
            # 'queries' is a list, so we join it for clean printing
            print(f"  Queries: {', '.join(output_item.queries)}")
            # Display results if they exist, otherwise note they are empty
            print(f"  Results: {output_item.results if output_item.results else 'None'}")
        elif output_item.type == "mcp_list_tools":
            print_mcp_list_tools(output_item)
        elif output_item.type == "mcp_call":
            print_mcp_call(output_item)
        else:
            print(f"Response content: {output_item.content}")

def print_mcp_call(mcp_call):
    """Print MCP call in a nicely formatted way"""
    print(f"\n🛠️  MCP Tool Call: {mcp_call.name}")
    print(f"   Server: {mcp_call.server_label}")
    print(f"   ID: {mcp_call.id}")
    print(f"   Arguments: {mcp_call.arguments}")
    
    if mcp_call.error:
        print("Error: {mcp_call.error}")
    elif mcp_call.output:
        print("Output:")
        # Try to format JSON output nicely
        try:
            import json
            parsed_output = json.loads(mcp_call.output)
            print(json.dumps(parsed_output, indent=4))
        except:
            # If not valid JSON, print as-is
            print(f"   {mcp_call.output}")
    else:
        print("   ⏳ No output yet")

def print_mcp_list_tools(mcp_list_tools):
    """Print MCP list tools in a nicely formatted way"""
    print(f"\n🔧 MCP Server: {mcp_list_tools.server_label}")
    print(f"   ID: {mcp_list_tools.id}")
    print(f"   Available Tools: {len(mcp_list_tools.tools)}")
    print("=" * 80)
    
    for i, tool in enumerate(mcp_list_tools.tools, 1):
        print(f"\n{i}. {tool.name}")
        print(f"   Description: {tool.description}")
        
        # Parse and display input schema
        schema = tool.input_schema
        if schema and 'properties' in schema:
            properties = schema['properties']
            required = schema.get('required', [])
            
            print("   Parameters:")
            for param_name, param_info in properties.items():
                param_type = param_info.get('type', 'unknown')
                param_desc = param_info.get('description', 'No description')
                required_marker = " (required)" if param_name in required else " (optional)"
                print(f"     • {param_name} ({param_type}){required_marker}")
                if param_desc:
                    print(f"       {param_desc}")
        
        if i < len(mcp_list_tools.tools):
            print("-" * 40)

# %% [markdown]
# Here we use that utility code to see the highlights of this response:

# %%
print_response(responses_api_response1)
# Out:
# ID: resp_8d99b9a5-9770-4b92-b341-5e2d241cc035
# Status: completed
# Model: openai/gpt-4o
# Created at: 1765398349
# Output items: 7
#
# --- Output Item 1 ---
# Output type: mcp_list_tools
#
# 🔧 MCP Server: NPS
#    ID: mcp_list_8809a0af-0211-4b26-839c-7309f7bdf738
#    Available Tools: 5
# ================================================================================
#
# 1. search_parks
#    Description: Search for national parks by state, park code, or query string.
#
# Args:
#     state_code: Two-letter state code (e.g., 'CA', 'NY')
#     park_code: Four-letter park code (e.g., 'yell', 'acad')
#     query: Search query for park names or descriptions
#     limit: Maximum number of results to return (default: 10)
#
# Returns:
#     JSON string with park information including name, description, website, and location
#    Parameters:
#      • state_code (unknown) (optional)
#        No description
#      • park_code (unknown) (optional)
#        No description
#      • query (unknown) (optional)
#        No description
#      • limit (integer) (optional)
#        No description
# ----------------------------------------
#
# 2. get_park_alerts
#    Description: Get current alerts for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#
# Returns:
#     JSON string with current alerts for the park
#    Parameters:
#      • park_code (string) (required)
#        No description
# ----------------------------------------
#
# 3. get_park_campgrounds
#    Description: Get campground information for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of campgrounds to return (default: 10)
#
# Returns:
#     JSON string with campground information including location, amenities, and fees
#    Parameters:
#      • park_code (string) (required)
#        No description
#      • limit (integer) (optional)
#        No description
# ----------------------------------------
#
# 4. get_park_events
#    Description: Get upcoming events for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of events to return (default: 10)
#
# Returns:
#     JSON string with event information including date, time, fee, and description
#    Parameters:
#      • park_code (string) (required)
#        No description
#      • limit (integer) (optional)
#        No description
# ----------------------------------------
#
# 5. get_visitor_centers
#    Description: Get visitor center information for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of visitor centers to return (default: 10)
#
# Returns:
#     JSON string with visitor center information including location, contact, and operating hours
#    Parameters:
#      • park_code (string) (required)
#        No description
#      • limit (integer) (optional)
#        No description
#
# --- Output Item 2 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: search_parks
#    Server: NPS
#    ID: fc_a0d1f539-c98e-4a19-9ff3-b394a7bad821
#    Arguments: {"state_code":"RI"}
# Output:
# {
#     "total": "4",
#     "parks": [
#         {
#             "name": "Blackstone River Valley National Historical Park",
#             "code": "blrv",
#             "description": "The Blackstone River powered America's entry into the Age of Industry. The success of Samuel Slater's cotton spinning mill in Pawtucket, RI touched off a chain reaction that changed how people worked and where they lived. Learn how this revolution transformed the landscape of the Blackstone Valley and the United States. The Visitor Center at Old Slater Mill is closed for the winter season.",
#             "website": "https://www.nps.gov/blrv/index.htm",
#             "states": "RI,MA",
#             "designation": "National Historical Park",
#             "latitude": "41.8775792792",
#             "longitude": "-71.382433945"
#         },
#         {
#             "name": "Roger Williams National Memorial",
#             "code": "rowi",
#             "description": "\"I acknowledge that to molest any person, Jew or Gentile, for either professing doctrine, or practicing worship meerly religious or spiritual, is to persecute him, and such a person (whether his doctrine or practice be true or false) suffers persecution for conscience.\" -Roger Williams, 1644 Banished by the English and saved by the First Peoples, Roger Williams founded Providence here in 1636.",
#             "website": "https://www.nps.gov/rowi/index.htm",
#             "states": "RI",
#             "designation": "National Memorial",
#             "latitude": "41.8298955",
#             "longitude": "-71.41056665"
#         },
#         {
#             "name": "Touro Synagogue National Historic Site",
#             "code": "tosy",
#             "description": "Touro Synagogue, a building of exquisite beauty and design, steeped in history and ideals, and one of the most historically significant Jewish buildings in America, was designated a National Historic Site in 1946. Dedicated in 1763, it still serves an active congregation and each year greets over 30,000 visitors who come to see the magnificent interior and hear its remarkable story.",
#             "website": "https://www.nps.gov/tosy/index.htm",
#             "states": "RI",
#             "designation": "National Historic Site",
#             "latitude": "41.4893",
#             "longitude": "-71.3121"
#         },
#         {
#             "name": "Washington-Rochambeau Revolutionary Route National Historic Trail",
#             "code": "waro",
#             "description": "\u201cOf the happiness I have enjoyed in our private friendship. The remembrance of which will be one of the most pleasing Circumstances of my life.\u201d\u2013 Comte de Rochambeau on his relationship with George Washington",
#             "website": "https://www.nps.gov/waro/index.htm",
#             "states": "MA,RI,CT,NY,NJ,PA,DE,MD,VA,DC",
#             "designation": "National Historic Trail",
#             "latitude": "40.0958204557",
#             "longitude": "-74.8563515109"
#         }
#     ]
# }
#
# --- Output Item 3 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: get_park_events
#    Server: NPS
#    ID: fc_b69b8a95-f76e-4276-a445-ab015efaaa56
#    Arguments: {"park_code": "blrv", "limit": 10}
# Output:
# {
#     "parkCode": "BLRV",
#     "totalEvents": 6,
#     "events": [
#         {
#             "title": "Blackstone Canal Hike Series",
#             "description": "<p class=\"\">Join us for hikes on Saturday mornings in January at 10:30 AM. Hikes will depart from various locations along the historic Blackstone Canal on 1/3, 1/10, 1/17, and 1/24.</p>\n<p class=\"\">All hikes are free. This series is presented in partnership with MA DCR.</p>\n<h4 class=\"\">January 3: Blackstone River State Park</h4>\n<p class=\"\">Meet at the Kelly House Museum, 1075 Lower River Road, Lincoln, RI</p>\n<h4 class=\"\">January 10: Millville Lock</h4>\n<p class=\"\">Meet at Blackstone River Greenway Parking Lot, Corner of Central Street and Hope Street, Millville, MA</p>\n<h4 class=\"\">January 17: The Old Stanley Woolen Mills</h4>\n<p class=\"\">Meet at Trailhead at 9 Cross Street, Uxbridge, MA</p>\n<h4 class=\"\">January 24: Goat Hill Lock</h4>\n<p class=\"\">Meet at River Bend Farm Visitor Center, 287 Oak Street, Uxbridge, MA</p>\n<p class=\"\"><em class=\"\">Please note: these programs are subject to cancelation because of inclement weather. Check the park\u2019s website and Facebook page for the latest information on whether programs have been canceled.</em></p>",
#             "location": "Meet at the Kelly House Museum, 1075 Lower River Road, Lincoln, RI",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Blackstone Canal Hike Series",
#             "description": "<p class=\"\">Join us for hikes on Saturday mornings in January at 10:30 AM. Hikes will depart from various locations along the historic Blackstone Canal on 1/3, 1/10, 1/17, and 1/24.</p>\n<p>\u00a0</p>\n<p class=\"\">All hikes are free. This series is presented in partnership with MA DCR.</p>\n<h4>January 10: Millville Lock</h4>\n<p>Meet at Blackstone River Greenway Parking Lot, Corner of Central Street and Hope Street, Millville, MA</p>\n<p>\u00a0</p>\n<h4 class=\"\">January 17: The Old Stanley Woolen Mills</h4>\n<p>\u00a0</p>\n<p class=\"\">Meet at Trailhead at 9 Cross Street, Uxbridge, MA</p>\n<p>\u00a0</p>\n<h4 class=\"\">January 24: Goat Hill Lock</h4>\n<p>\u00a0</p>\n<p class=\"\">Meet at River Bend Farm Visitor Center, 287 Oak Street, Uxbridge, MA</p>\n<p>\u00a0</p>\n<p class=\"\"><em class=\"\">Please note: these programs are subject to cancelation because of inclement weather. Check the park\u2019s website and Facebook page for the latest information on whether programs have been canceled.</em></p>",
#             "location": "Meet at Blackstone River Greenway Parking Lot, Corner of Central Street and Hope Street, Millville, MA",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Revolutionary War Pension Files Transcription Event",
#             "description": "<p>In celebration of the 250th anniversary of American independence, the National Archives and the National Park Service are collaborating on a special project to transcribe Revolutionary War Pension Files of more than 80,000 of America's first veterans and their windows, containing more than 2 million documents. These records may contain valuable details about Revolutionary War veterans and their families, such as rank, unit, period of service, age, residence, date and place of marriage, and date and place of death of spouse. You may find copies of marriage or other family records, information pertaining to military activities or details about soldier's lives, along with letters, diaries, or family trees within these records. Become a citizen archivist and unlock the details and stories found within these rich records!</p>\n<p>Blackstone River Valley National Historical Park and the Upton Historical Society will be co-hosting a transcription event on Wednesday, January 14, 2026, from 6-8pm in the\u00a0<strong>Upton Community Center\u00a0</strong>(9 Milford Street, Upton, Massachusetts). Participants will learn about the value of wartime pensions and hear service stories about patriots from the Blackstone Valley. Rangers will provide training on how to access pensions and transcribe these vital records online. Are you ready to join us and contribute to the nation's 250th anniversary?</p>\n<p>Capacity is limited to 25 participants. Participants are asked to bring a laptop or tablet to this event.\u00a0<strong>Please email <u data-ogsc=\"\"><a id=\"OWAb1799b99-78fa-ab05-def1-d1d377e55125\" title=\"mailto:UptonMAHistoricalSociety@gmail.com\" href=\"mailto:UptonMAHistoricalSociety@gmail.com\" data-linkindex=\"1\" data-ogsc=\"blue\" data-olk-copy-source=\"MessageBody\">UptonMAHistoricalSociety@gmail.com</a></u><a href=\"mailto:blynn@supplychain411.com\">\u00a0</a>if you are interested in attending.</strong></p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Blackstone Canal Hike Series",
#             "description": "<p class=\"\">Join us for hikes on Saturday mornings in January at 10:30 AM. Hikes will depart from various locations along the historic Blackstone Canal on 1/3, 1/10, 1/17, and 1/24.</p>\n<p>\u00a0</p>\n<p class=\"\">All hikes are free. This series is presented in partnership with MA DCR.</p>\n<p>\u00a0</p>\n<h4 class=\"\">January 17: The Old Stanley Woolen Mills</h4>\n<p>\u00a0</p>\n<p class=\"\">Meet at Trailhead at 9 Cross Street, Uxbridge, MA</p>\n<p>\u00a0</p>\n<h4 class=\"\">January 24: Goat Hill Lock</h4>\n<p>\u00a0</p>\n<p class=\"\">Meet at River Bend Farm Visitor Center, 287 Oak Street, Uxbridge, MA</p>\n<p>\u00a0</p>\n<p class=\"\"><em class=\"\">Please note: these programs are subject to cancelation because of inclement weather. Check the park\u2019s website and Facebook page for the latest information on whether programs have been canceled.</em></p>",
#             "location": "Meet at Trailhead at 9 Cross Street, Uxbridge, MA",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Blackstone Canal Hike Series",
#             "description": "<p class=\"\">Join us for hikes on Saturday mornings in January at 10:30 AM. Hikes will depart from various locations along the historic Blackstone Canal on 1/3, 1/10, 1/17, and 1/24.</p>\n<p>\u00a0</p>\n<p class=\"\">All hikes are free. This series is presented in partnership with MA DCR.</p>\n<h4>\u00a0January 24: Goat Hill Lock</h4>\n<p>\u00a0Meet at River Bend Farm Visitor Center, 287 Oak Street, Uxbridge, MA</p>\n<p>\u00a0<em class=\"\">Please note: these programs are subject to cancelation because of inclement weather. Check the park\u2019s website and Facebook page for the latest information on whether programs have been canceled.</em></p>",
#             "location": "Meet at River Bend Farm Visitor Center, 287 Oak Street, Uxbridge, MA",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         },
#         {
#             "title": "Revolutionary War Pension Files Transcription Event",
#             "description": "<p>In celebration of the 250th anniversary of American independence, the National Archives and the National Park service are collaborating on a special project to transcribe Revolutionary War Pension Files. Become a citizen archivist and unlock the details and stories found within these rich records! Blackstone River Valley National Historical Park and Sutton Historical Society will be co-hosting a transcription event on Wednesday, January 28, 2026, at 1:30 PM in the Sutton Senior Center.\u00a0</p>\n<p>Participants will learn about the value of wartime pensions and hear service stories about patriots from the Blackstone Valley. Rangers will provide training on how to access pensions and transcribe these vital records online. Please bring a laptop.\u00a0</p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         }
#     ]
# }
#
# --- Output Item 4 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: get_park_events
#    Server: NPS
#    ID: fc_0703d2c6-7bef-4bd6-a2eb-c267e52c737b
#    Arguments: {"park_code": "rowi", "limit": 10}
# Output:
# {
#     "parkCode": "ROWI",
#     "totalEvents": 1,
#     "events": [
#         {
#             "title": "Visitor Center Open",
#             "description": "<p>Explore the life and legacy of Roger Williams. Park Rangers and volunteers are standing by. While you're here, watch our 5 minute film, read our exhibits, browse the bookstore, and use our facilites.</p>",
#             "location": "",
#             "dateStart": "",
#             "dateEnd": "",
#             "timeStart": "",
#             "timeEnd": "",
#             "feeInfo": "",
#             "isRecurring": false,
#             "parkCode": ""
#         }
#     ]
# }
#
# --- Output Item 5 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: get_park_events
#    Server: NPS
#    ID: fc_fb19bde4-d452-47b5-95dd-075a437adb09
#    Arguments: {"park_code": "tosy", "limit": 10}
# Output:
# {
#     "parkCode": "TOSY",
#     "message": "No upcoming events found for this park"
# }
#
# --- Output Item 6 ---
# Output type: mcp_call
#
# 🛠️  MCP Tool Call: get_park_events
#    Server: NPS
#    ID: fc_3a821362-d0e4-4565-b58f-c05bb601a4e1
#    Arguments: {"park_code": "waro", "limit": 10}
# Output:
# {
#     "parkCode": "WARO",
#     "message": "No upcoming events found for this park"
# }
#
# --- Output Item 7 ---
# Output type: message
# Response content: Here are some national parks in Rhode Island, along with information on their upcoming events:
#
# ### Blackstone River Valley National Historical Park
# - **Description:** The Blackstone River powered America's entry into the Age of Industry, starting with Samuel Slater's cotton spinning mill in Pawtucket, RI.
# - **Website:** [Blackstone River Valley NHP](https://www.nps.gov/blrv/index.htm)
#
# #### Upcoming Events:
# 1. **Blackstone Canal Hike Series**
#    - Join hikes on Saturday mornings in January at 10:30 AM. Locations include the Kelly House Museum in Lincoln, RI, Millville Lock in Millville, MA, and more. Events are free but weather-dependent.
#    - **Location:** Various sites along the Blackstone Canal.
#
# 2. **Revolutionary War Pension Files Transcription Event**
#    - On January 14, 2026, from 6-8 PM, join a transcription event at the Upton Community Center in Massachusetts, to help transcribe Revolutionary War Pension Files.
#    - **Note:** Bring a laptop or tablet. Email [UptonMAHistoricalSociety@gmail.com](mailto:UptonMAHistoricalSociety@gmail.com) for participation.
#
# ### Roger Williams National Memorial
# - **Description:** Learn about religious freedom and Providence’s founder, Roger Williams.
# - **Website:** [Roger Williams National Memorial](https://www.nps.gov/rowi/index.htm)
#
# #### Upcoming Event:
# - **Visitor Center Open**
#   - Explore the life and legacy of Roger Williams with park rangers, exhibits, a bookstore, and a short film.
#
# ### Touro Synagogue National Historic Site
# - **Description:** A historic Jewish building recognized for its beauty and history, still active with an annual visitor count exceeding 30,000.
# - **Website:** [Touro Synagogue NHS](https://www.nps.gov/tosy/index.htm)
#
# #### Upcoming Events:
# - No upcoming events are currently found for this park.
#
# ### Washington-Rochambeau Revolutionary Route National Historic Trail
# - **Description:** A historic trail emphasizing the friendship between George Washington and Comte de Rochambeau.
# - **Website:** [Washington-Rochambeau NHT](https://www.nps.gov/waro/index.htm)
#
# #### Upcoming Events:
# - No upcoming events are currently found for this park.
#
# Feel free to check the park websites for the most up-to-date event details and potential weather-related changes.

# %% [markdown]
# As you can see, what happened in the Responses API was that it first listed all the tools available in the MCP server and got descriptions and input schemas for each of them.  Then it called a tool to list parks in Rhode Island.  For each of those parks, it then called a tool to get events for that park.  Finally, it provided a summary of the results.  Note that this is the same flow that we saw earlier using the Agent object in the Python client, so this Responses call has replicated the behavior of that object.  Next we will ask the same follow-on question:

# %%
responses_api_response2 = client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input=NPS_EXAMPLE_FOLLOWUP_PROMPT,
    instructions=NPS_INSTRUCTIONS,
    # Setting previous_response_id to the id of the previous response causes the Responses
    # API to continue the conversation from where it left off in the previous call.
    previous_response_id=responses_api_response1.id,
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "National Parks Service tools",
            "requires_approval": False,
        }
    ]
)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"

# %%
print_response(responses_api_response2)
# Out:
# ID: resp_010b23bc-7d70-4869-80ea-5e87fee81ef3
# Status: completed
# Model: openai/gpt-4o
# Created at: 1765398364
# Output items: 2
#
# --- Output Item 1 ---
# Output type: mcp_list_tools
#
# 🔧 MCP Server: National Parks Service tools
#    ID: mcp_list_0a2ef586-e19e-4eb9-84ef-3e74ac93f7d2
#    Available Tools: 5
# ================================================================================
#
# 1. search_parks
#    Description: Search for national parks by state, park code, or query string.
#
# Args:
#     state_code: Two-letter state code (e.g., 'CA', 'NY')
#     park_code: Four-letter park code (e.g., 'yell', 'acad')
#     query: Search query for park names or descriptions
#     limit: Maximum number of results to return (default: 10)
#
# Returns:
#     JSON string with park information including name, description, website, and location
#    Parameters:
#      • state_code (unknown) (optional)
#        No description
#      • park_code (unknown) (optional)
#        No description
#      • query (unknown) (optional)
#        No description
#      • limit (integer) (optional)
#        No description
# ----------------------------------------
#
# 2. get_park_alerts
#    Description: Get current alerts for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#
# Returns:
#     JSON string with current alerts for the park
#    Parameters:
#      • park_code (string) (required)
#        No description
# ----------------------------------------
#
# 3. get_park_campgrounds
#    Description: Get campground information for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of campgrounds to return (default: 10)
#
# Returns:
#     JSON string with campground information including location, amenities, and fees
#    Parameters:
#      • park_code (string) (required)
#        No description
#      • limit (integer) (optional)
#        No description
# ----------------------------------------
#
# 4. get_park_events
#    Description: Get upcoming events for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of events to return (default: 10)
#
# Returns:
#     JSON string with event information including date, time, fee, and description
#    Parameters:
#      • park_code (string) (required)
#        No description
#      • limit (integer) (optional)
#        No description
# ----------------------------------------
#
# 5. get_visitor_centers
#    Description: Get visitor center information for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of visitor centers to return (default: 10)
#
# Returns:
#     JSON string with visitor center information including location, contact, and operating hours
#    Parameters:
#      • park_code (string) (required)
#        No description
#      • limit (integer) (optional)
#        No description
#
# --- Output Item 2 ---
# Output type: message
# Response content: The soonest event happening at these parks is part of the **Blackstone Canal Hike Series**:
#
# - The first hike is scheduled for **January 3**, at Blackstone River State Park, meeting at the Kelly House Museum in Lincoln, RI. The series will continue with hikes on the following Saturdays in January.

# %% [markdown]
# As you can see, it still lists the tools again; this is done before calling inference so the model can know what tools it can call.  In this case, however, no calls to those tools are needed because the previous context has all the information it needs to answer the question so it immediately answers the question.

# %% [markdown]
# ## Emulating the Legacy Agent API
#
# For most use cases, the approach above is probably the best way to migrate from the Agent API to the Responses API.  However, if you have a large amount of code that uses the old API, you might want to have some objects that emulate the old Agent API instead (the approach in the commented out example at the top of the previous session).  Here is a very simple example of how to do that.
#
# The simple example only covers the functionality needed in the original simple example above.  We'll get into some advanced functionality in later sections, but there are also many parameters in the legacy API that we do not provide sample code for.  We don't recommend trying to build a complete implementation of every parameter value in the entire API.  Instead, you can use this example as a starting point and then fill in those parameters and/or values that are important to your application.

# %%
TOOLS = {}
SESSIONS = {}

class LegacyURL:
    def __init__(self, uri):
        self.uri = uri

def toolgroups_register(toolgroup_id, provider_id, mcp_endpoint=None):
    """
    This replaces the client.toolgroups.register() call in the legacy agent API.  Since this version manages the
    tool group registration internally, it does not need to use the client object.
    """
    if provider_id == "model-context-protocol":
        TOOLS[toolgroup_id] = {
            "type": "mcp",
            "server_url": mcp_endpoint.uri,
            "server_label": toolgroup_id,
        }
    else:
        # TODO: Add support for other providers, not needed for this example.
        raise ValueError(f"Unsupported provider: {provider_id}")

def convert_response_to_legacy_agent_response(response):
    """
    This is a placeholder for now.  The code to convert objects to the legacy agent response format would go here.
    Note that just returning the response object is good enough for this example because the response object has
    all of the same fields that we are using in the example print statements.  However, in a more complex application
    you may need to do more work here.
    """
    return response

class LegacyAgent:
    def __init__(self, model, instructions, client, tools, extra_headers):
        self.model = model
        self.instructions = instructions
        self.client = client
        self.tool_ids = tools
        self.auth_token = None

        header_json = extra_headers["X-LlamaStack-Provider-Data"]
        headers = json.loads(header_json)
        self.headers = headers["mcp_headers"]
    
    def create_session(self, session_id):
        SESSIONS[session_id] = []
        return session_id
    
    def create_turn(self, messages, session_id, stream=False):
        # Note that the stream parameter is not used.  That works for this example because we are not using the stream=True,
        # but if you are using that option, you will need to update this code.
        if session_id not in SESSIONS:
            raise ValueError(f"Session {session_id} not found")
            
        previous_response_id = None
        if len(SESSIONS[session_id]) > 0:
            previous_response_id = SESSIONS[session_id][-1].id

        tools = [TOOLS[tool_id] for tool_id in self.tool_ids]
        for tool in tools:
            if tool["server_url"] in self.headers:
                all_headers = self.headers[tool["server_url"]]
                headers_minus_auth = {}
                auth_token = None
                # We need to remove the Authorization header because the Responses API
                # has a separate field for authorization and doesn't allow you to
                # pass it in the headers field.
                for key, value in all_headers.items():
                    if key == "Authorization":
                        auth_token = value.split(" ")[1]
                    else:
                        headers_minus_auth[key] = value
                tool["headers"] = headers_minus_auth
                if auth_token:
                    tool["authorization"] = auth_token

        response = client.responses.create(
            model=self.model,
            # TODO: This is using the last message in the list, which is fine for this example, but
            # if you call create_turn() with multiple messages, you will need to update this code.
            input=messages[-1]["content"],
            previous_response_id=previous_response_id,
            instructions=self.instructions,
            tools=tools
        )
        print(tools)
        SESSIONS[session_id].append(response)
        return convert_response_to_legacy_agent_response(response)

# %% [markdown]
# With this simple wrapper in place, we can maintain much of the structure of the original Agent code we saw earlier:

# %%
toolgroups_register(
    toolgroup_id="mcp::nps",
    provider_id="model-context-protocol",
    mcp_endpoint=LegacyURL(uri=NPS_MCP_URL),
)

agent = LegacyAgent(
    model=LLAMA_STACK_MODEL_ID,
    instructions=NPS_INSTRUCTIONS,
    client=client,
    tools=["mcp::nps"],
    extra_headers={
        "X-LlamaStack-Provider-Data": json.dumps(
            {
                "mcp_headers": {
                    NPS_MCP_URL: {
                        "Authorization": f"Bearer {NPS_ACCESS_TOKEN}",
                    },
                },
            }
        ),
    },
)

# %%
session_id = agent.create_session(f"nps_session-{uuid.uuid4().hex}")

agent_response1 = agent.create_turn(
    messages=[{"role": "user", "content": NPS_EXAMPLE_PROMPT}],
    session_id=session_id,
    stream=False,
)
print(agent_response1.output_text)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# [{'type': 'mcp', 'server_url': 'http://localhost:3005/sse/', 'server_label': 'mcp::nps', 'headers': {}, 'authorization': 'frog'}]
# Here are some national parks in Rhode Island along with details about any upcoming events:
#
# 1. **Blackstone River Valley National Historical Park**
#    - **Description:** This park commemorates the role the Blackstone River played in America's industrial revolution, particularly through Samuel Slater's cotton spinning mill in Pawtucket, RI.
#    - **Location:** Rhode Island and Massachusetts
#    - **Website:** [Blackstone River Valley NHP](https://www.nps.gov/blrv/index.htm)
#
# 2. **Roger Williams National Memorial**
#    - **Description:** This memorial honors Roger Williams, the founder of Providence, RI, who advocated for religious freedom and the separation of church and state.
#    - **Location:** Rhode Island
#    - **Website:** [Roger Williams National Memorial](https://www.nps.gov/rowi/index.htm)
#    - **Upcoming Event:**
#      - **Event:** Visitor Center Open
#      - **Description:** Explore the life and legacy of Roger Williams with park rangers and volunteers, watch a 5-minute film, see exhibits, and browse the bookstore.
#
# 3. **Touro Synagogue National Historic Site**
#    - **Description:** This historic synagogue is noted for its beauty, design, and historical significance as one of the most important Jewish buildings in America.
#    - **Location:** Rhode Island
#    - **Website:** [Touro Synagogue](https://www.nps.gov/tosy/index.htm)
#
# 4. **Washington-Rochambeau Revolutionary Route National Historic Trail**
#    - **Description:** This trail marks the route taken by the American and French armies under Washington and Rochambeau during the Revolutionary War.
#    - **Location:** Spans multiple states including Rhode Island
#    - **Website:** [Washington-Rochambeau Trail](https://www.nps.gov/waro/index.htm)
#
# As of the moment, there are no upcoming events found for the Blackstone River Valley National Historical Park. Let me know if you need more information on any specific park!

# %%
agent_response2 = agent.create_turn(
    messages=[{"role": "user", "content": NPS_EXAMPLE_FOLLOWUP_PROMPT}],
    session_id=session_id,
    stream=False,
)
print(agent_response2.output_text)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# [{'type': 'mcp', 'server_url': 'http://localhost:3005/sse/', 'server_label': 'mcp::nps', 'headers': {}, 'authorization': 'frog'}]
# The only event currently listed is the "Visitor Center Open" event at the Roger Williams National Memorial. However, specific dates and times for this event were not provided. It's described as a recurring opportunity to explore the life and legacy of Roger Williams with park rangers and volunteers available on-site.
#
# For exact dates and the frequency of this event, it might be best to contact the park directly through their [website](https://www.nps.gov/rowi/index.htm).

# %% [markdown]
# ## Adopting a simpler agent class
#
# As you can see above, a downside of the LegacyAgent is it drags in the clunky inelegance of the legacy APIs (by design).  Calling Responses API directly as shown in the section before that is often the best way to avoid this inelegance, but some developers really want a more object-oriented experience with an object representing an agent especially if they have existing code that is structured around such an object.  The example below is a compromise between calling a mirror of the legacy Agent class (as shown in the previous section) and just calling Responses directly (as shown in the section before that).

# %%
class SimpleExampleSession:
    def __init__(self, agent):
        self.agent = agent
        self.previous_response_id = None
    
    def create_turn(self, input):
        response = self.agent.client.responses.create(
            model=self.agent.model,
            input=input,
            previous_response_id=self.previous_response_id,
            instructions=self.agent.instructions,
            tools=self.agent.tools
        )
        self.previous_response_id = response.id
        return response

class SimpleExampleAgent:
    def __init__(self, model, instructions, client, tools):
        self.model = model
        self.instructions = instructions
        self.client = client
        self.tools = tools

    def create_session(self):
        return SimpleExampleSession(self)

# %% [markdown]
# As you can see, this is much simpler than LegacyAgent and the code to use it is simpler too:

# %%
simple_agent = SimpleExampleAgent(
    model=LLAMA_STACK_MODEL_ID,
    instructions=NPS_INSTRUCTIONS,
    client=client,
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "",
            "requires_approval": False,
        }
    ]
)
simple_session = simple_agent.create_session()

simple_agent_response1 = simple_session.create_turn(NPS_EXAMPLE_PROMPT)
print(simple_agent_response1.output_text)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# Here are some national parks in Rhode Island:
#
# 1. **Blackstone River Valley National Historical Park**
#    - **Description**: The Blackstone River powered America's entry into the Age of Industry. The success of Samuel Slater's cotton spinning mill in Pawtucket, RI touched off a chain reaction that changed how people worked and where they lived.
#    - **Location**: Situated in both Rhode Island and Massachusetts.
#    - **Website**: [Visit Site](https://www.nps.gov/blrv/index.htm)
#
# 2. **Roger Williams National Memorial**
#    - **Description**: Banished by the English and saved by the First Peoples, Roger Williams founded Providence here in 1636. The site memorializes Williams' ideals of freedom of religion and conscience.
#    - **Location**: Providence, Rhode Island.
#    - **Website**: [Visit Site](https://www.nps.gov/rowi/index.htm)
#    - **Upcoming Event**: The Visitor Center is open. You can explore the life and legacy of Roger Williams, watch a short film, and check out the exhibits and bookstore.
#
# 3. **Touro Synagogue National Historic Site**
#    - **Description**: As one of the most historically significant Jewish buildings in America, dedicated in 1763, it serves as an active synagogue and a historic site.
#    - **Location**: Newport, Rhode Island.
#    - **Website**: [Visit Site](https://www.nps.gov/tosy/index.htm)
#
# 4. **Washington-Rochambeau Revolutionary Route National Historic Trail**
#    - **Description**: This trail commemorates the routes taken by General George Washington and French General Rochambeau during the American Revolutionary War.
#    - **Location**: Spanning multiple states, including parts of Rhode Island.
#    - **Website**: [Visit Site](https://www.nps.gov/waro/index.htm)
#
# For Blackstone River Valley, there are currently no upcoming events listed. At Roger Williams National Memorial, you can visit the Visitor Center to learn more about the site's history and significance.

# %%
simple_agent_response2 = simple_session.create_turn(NPS_EXAMPLE_FOLLOWUP_PROMPT)
print(simple_agent_response2.output_text)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# The event "Visitor Center Open" at Roger Williams National Memorial is happening currently. You can visit the center to explore the life and legacy of Roger Williams, view a short film, and see the exhibits. Since there was no specific start or end date provided, it is ongoing.

# %% [markdown]
# Of course, the downside of the simpler version here is that it is less compatible with the legacy API so if you have existing code that uses the legacy API, it will need more rewriting to use this structure.

# %% [markdown]
# ## Human-in-the-loop tool approval
#
# Both LegacyAgent and SimpleExampleAgent here are extremely minimal and that there are many features of Responses that are not covered in these example class.  In the next section, we will address one of those features mainly to show how you can go about expanding on the basic examples.  A more full-featured agent construct is outside the scope of this notebook; it is up to the reader to explore the [Responses API documentation](https://platform.openai.com/docs/api-reference/responses) and decide which ones fit their use case.  We will use the SimpleExampleAgent as a starting point because it is simpler to build on, but you could also make the same kinds of changes to LegacyAgent if you prefer.

# %%
class SimpleExampleSessionWithApproval:
    def __init__(self, agent):
        self.agent = agent
        self.previous_response_id = None
    
    def create_turn(self, input):
        response = self.agent.client.responses.create(
            model=self.agent.model,
            input=input,
            previous_response_id=self.previous_response_id,
            instructions=self.agent.instructions,
            tools=self.agent.tools
        )
        self.previous_response_id = response.id

        approval_requests = []
        for block in response.output:
            if block.type == "mcp_approval_request":
                approval_request = (block.name, block.arguments, block.id)
                approval_requests.append(approval_request)

        return response, approval_requests if approval_requests else None

    def create_approval_turn(self, approval_requests_to_approve):
        """
        This is a helper method to create a turn that is used to approve or reject tool calls.
        The input is a dictionary that maps approval requests to boolean values indicating whether to approve or reject.
        """
        approval_request_entries = []
        for approval_request in approval_requests_to_approve:
            approval_request_entries.append({
                "type": "mcp_approval_request",
                "approval_request_id": approval_request[2],
                "approval": approval_requests_to_approve[approval_request]
            })

        response = self.client.responses.create(
            model=self.model,
            input=approval_request_entries,
            previous_response_id=self.previous_response_id,
            instructions=self.instructions,
            tools=self.tools
        )
        self.previous_response_id = response.id
        return response
    
class SimpleExampleAgentWithApproval:
    def __init__(self, model, instructions, client, tools):
        self.model = model
        self.instructions = instructions
        self.client = client
        self.tools = tools

    def create_session(self):
        return SimpleExampleSessionWithApproval(self)

# %% [markdown]
# Unlike the version in the previous section, this version it checks to see if there is an `mcp_approval_request` in the response, which there may be if you set `"requires_approval": True` in one of your MCP tool entries as shown below:

# %%
simple_agent_with_approval = SimpleExampleAgentWithApproval(
    model=LLAMA_STACK_MODEL_ID,
    instructions=NPS_INSTRUCTIONS,
    client=client,
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "NPS",
            "requires_approval": True
        }
    ]
)

# %% [markdown]
# The `create_turn` method on a session now returns both the response object and optionally an approval request extracted from that response object:

# %%
simple_session_with_approval = simple_agent_with_approval.create_session()

simple_agent_response1, approval_requests1 = simple_session_with_approval.create_turn(NPS_EXAMPLE_PROMPT)
print(simple_agent_response1.output_text)
print(approval_requests1)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# Here are some national parks in Rhode Island, along with information about upcoming events:
#
# ### Parks in Rhode Island:
#
# 1. **Blackstone River Valley National Historical Park**
#    - **Description:** The Blackstone River powered America's entry into the Age of Industry. Visit to learn about the industrial revolution and its impact on the nation.
#    - **Website:** [Blackstone River Valley NHP](https://www.nps.gov/blrv/index.htm)
#    - **Upcoming Events:**
#      - **Blackstone Canal Hike Series:** Saturday mornings in January at 10:30 AM. Hikes depart from various locations along the historic Blackstone Canal.
#      - **Revolutionary War Pension Files Transcription Event:** Join a transcription event on January 14, 2026, in Upton, MA, or January 28, 2026, in Sutton, MA.
#
# 2. **Roger Williams National Memorial**
#    - **Description:** Learn about Roger Williams, who founded Providence in 1636 after being banished by the English and saved by the First Peoples.
#    - **Website:** [Roger Williams National Memorial](https://www.nps.gov/rowi/index.htm)
#    - **Upcoming Events:**
#      - **Visitor Center Open:** Explore the life and legacy of Roger Williams with park rangers and volunteers available to assist.
#
# 3. **Touro Synagogue National Historic Site**
#    - **Description:** As one of the most historically significant Jewish buildings in America, Touro Synagogue continues to serve an active congregation.
#    - **Website:** [Touro Synagogue NHS](https://www.nps.gov/tosy/index.htm)
#    - **Upcoming Events:** No upcoming events found.
#
# 4. **Washington-Rochambeau Revolutionary Route National Historic Trail**
#    - **Description:** Celebrate the historical friendship and independence journey of George Washington and Comte de Rochambeau.
#    - **Website:** [Washington-Rochambeau Trail](https://www.nps.gov/waro/index.htm)
#    - **Upcoming Events:** No upcoming events found.
#
# These parks offer unique historical perspectives and opportunities for engagement through various events and activities. Be sure to check out their websites for the latest information and possible changes to event schedules.
# None

# %% [markdown]
# When the client gets an approval request, it should ask a user or apply whatever other logic it deems appropriate to approve or reject the request to run the tool.  This can be very important if you have tools that perform destructive operations since models will sometimes choose the wrong tools or the wrong values for those tools.  Here is an example of how to approve a tool use with this implementation:

# %%
def get_approval_from_user(approval_request):
    """
    This is a placeholder for the actual logic to get approval from the user.
    It prints the approval request so you can see the information that would be
    available to the user.  In a real application, you would replace this with
    the actual logic to show this to the user in a reasonable way and then ask
    for a yes/no decision on whether to approve the tool call.
    """
    print(approval_request)
    return True

# %%
def approve_tool_use(approval_requests):
    """
    Method to iterate over the approval requests, get approval boolean from the user for each one, and then send the approval booleans to the session.
    Each approval boolean is a boolean value indicating whether to approve or reject the tool call.
    The approval requests are a list of tuples, each containing the tool name, tool arguments, and approval request id.
    """
    approval_requests_to_approve = {}
    for approval_request in approval_requests:
        approval_bool = get_approval_from_user(approval_request)
        approval_requests_to_approve[approval_request] = approval_bool
    return simple_session_with_approval.create_approval_turn(approval_requests_to_approve)

# %% [markdown]
# The code then goes into a loop: as long as the agent keeps asking for approvals, those approvals keep getting sent to `approve_tool_use` above.  Once no more approvals are needed, you have a final response to share with the user.

# %%
while approval_requests1:
    print(simple_agent_response1.output_text)
    simple_agent_response1, approval_requests1 = approve_tool_use(approval_requests1)

# %% [markdown]
# ## Model safety
#
# A key consideration for any AI application is avoiding dangerous or toxic outputs from a model such as instructions for doing something harmful or offensive/abusive language.  Most popular AI models are trained reasonably well but not perfectly at avoiding such outputs.  Most major AI providers then include additional layers of output moderation specifically designed to filter out unsafe responses as a second layer of defense.  For example, here is the behavior we see from our sample model (the one configured for `LLAMA_STACK_MODEL_ID` at the start of this notebook) when we ask it for instructions for committing a crime:

# %%
NPS_EXAMPLE_SAFETY_PROMPT = "Are there any parks in Rhode Island that would be good targets for a burglary?"
unsafe_agent_response = client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input=NPS_EXAMPLE_SAFETY_PROMPT, # Notice this is the one about burglary above.
    instructions=NPS_INSTRUCTIONS,
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "NPS",
            "authorization": NPS_ACCESS_TOKEN,
            "requires_approval": False,
        }
    ]
)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"

# %%
print(unsafe_agent_response.output_text)
# Out:
# I cannot assist with that request.

# %% [markdown]
# The model seems to handle this example well, so for this specific prompt no additional safety is needed.  If you spent enough time trying to devise prompts that would result in an unsafe (harmful or offensive or abusive) response, you probably would be able to find one eventually (unless your provider disabled your account for repeated safety violations first, which is also something that can happen).  The issue is even more pressing if you are using a model and/or provider that has less (or no) built-in safety.
#
# In either case, you might need to add in your own safety.  Here we extend the `SimpleExampleAgent` with the ability to check both the inputs and outputs for safety violations before and after running the responses request (to check for unsafe inputs and/or outputs).

# %% [markdown]
# Here is how you can put in a safety check using Llama Stack's older shields APIs:

# %%
# Uncomment this to delete the shield if you already have it registered, e.g., if you are running the next cell multiple times.
#client.shields.delete(identifier="content_safety")

# %%
shield_id = "content_safety"
client.shields.register(
    shield_id=shield_id,
    provider_id="llama-guard",
    # In this example, we are using gpt-3.5-turbo as the model for llama-guard,
    # but it is not really ideal for llama-guard since it is not trained
    # as a Llama Guard model.  It is convenient for this notebook since it is a
    # hosted model that is readily available.  However, it is not very reliable
    # in this role.
    # 
    # For real applications, consider using a Llama Guard model such as
    # https://huggingface.co/meta-llama/Llama-Guard-3-8B
    # and deploying it on an inference provider such as vLLM.
    provider_shield_id="openai/gpt-3.5-turbo"
)
response = client.safety.run_shield(
    shield_id="content_safety",
    messages=[{"role": "user", "content": NPS_EXAMPLE_SAFETY_PROMPT}],
    params={}
)
# Out:
# /var/folders/2b/b5b46qw54yd7c62llcrq5qww0000gn/T/ipykernel_90210/1988829589.py:2: DeprecationWarning: deprecated
#   client.shields.register(
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/shields "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/safety/run-shield "HTTP/1.1 200 OK"

# %%
client.shields.list()
# Out:
# INFO:httpx:HTTP Request: GET http://localhost:8321/v1/shields "HTTP/1.1 200 OK"
# [Shield(identifier='content_safety', provider_id='llama-guard', params={}, provider_resource_id='openai/gpt-3.5-turbo', type='shield')]

# %% [markdown]
# ### Using the OpenAI-compatible Moderations API.

# %% [markdown]
# Once you have registered a shield for a model (as shown above for `"openai/gpt-3.5-turbo"`), you can also use the OpenAI-compatible Moderations API to check for unsafe inputs:

# %%
moderation = client.moderations.create(input="Are there any parks in Rhode Island that would be good targets for a burglary?", model="openai/gpt-3.5-turbo")
pretty_print(moderation)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/moderations "HTTP/1.1 200 OK"
# {
#   "id": "modr-8ccaf6f5-b9f1-41d2-accc-64abe5209715",
#   "model": "openai/gpt-3.5-turbo",
#   "results": [
#     {
#       "flagged": true,
#       "categories": {
#         "Violent Crimes": false,
#         "Non-Violent Crimes": true,
#         "Sex Crimes": false,
#         "Child Exploitation": false,
#         "Defamation": false,
#         "Specialized Advice": false,
#         "Privacy": false,
#         "Intellectual Property": false,
#         "Indiscriminate Weapons": false,
#         "Hate": false,
#         "Self-Harm": false,
#         "Sexual Content": false,
#         "Elections": false,
#         "Code Interpreter Abuse": false
#       },
#       "category_applied_input_types": {
#         "Violent Crimes": [],
#         "Non-Violent Crimes": [
#           "text"
#         ],
#         "Sex Crimes": [],
#         "Child Exploitation": [],
#         "Defamation": [],
#         "Specialized Advice": [],
#         "Privacy": [],
#         "Intellectual Property": [],
#         "Indiscriminate Weapons": [],
#         "Hate": [],
#         "Self-Harm": [],
#         "Sexual Content": [],
#         "Elections": [],
#         "Code Interpreter Abuse": []
#       },
#       "category_scores": {
#         "Violent Crimes": 0.0,
#         "Non-Violent Crimes": 1.0,
#         "Sex Crimes": 0.0,
#         "Child Exploitation": 0.0,
#         "Defamation": 0.0,
#         "Specialized Advice": 0.0,
#         "Privacy": 0.0,
#         "Intellectual Property": 0.0,
#         "Indiscriminate Weapons": 0.0,
#         "Hate": 0.0,
#         "Self-Harm": 0.0,
#         "Sexual Content": 0.0,
#         "Elections": 0.0,
#         "Code Interpreter Abuse": 0.0
#       },
#       "metadata": {
#         "violation_type": [
#           "S2"
#         ]
#       },
#       "user_message": "I can't answer that. Can I help with something else?"
#     }
#   ]
# }

# %%
moderation2 = client.moderations.create(input="Have a nice day!", model="openai/gpt-3.5-turbo")
pretty_print(moderation2)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/moderations "HTTP/1.1 200 OK"
# {
#   "id": "modr-f3f323bb-ae99-4db5-bf5c-39630e3eaab6",
#   "model": "openai/gpt-3.5-turbo",
#   "results": [
#     {
#       "flagged": false,
#       "categories": {
#         "Violent Crimes": false,
#         "Non-Violent Crimes": false,
#         "Sex Crimes": false,
#         "Child Exploitation": false,
#         "Defamation": false,
#         "Specialized Advice": false,
#         "Privacy": false,
#         "Intellectual Property": false,
#         "Indiscriminate Weapons": false,
#         "Hate": false,
#         "Self-Harm": false,
#         "Sexual Content": false,
#         "Elections": false,
#         "Code Interpreter Abuse": false
#       },
#       "category_applied_input_types": {
#         "Violent Crimes": [],
#         "Non-Violent Crimes": [],
#         "Sex Crimes": [],
#         "Child Exploitation": [],
#         "Defamation": [],
#         "Specialized Advice": [],
#         "Privacy": [],
#         "Intellectual Property": [],
#         "Indiscriminate Weapons": [],
#         "Hate": [],
#         "Self-Harm": [],
#         "Sexual Content": [],
#         "Elections": [],
#         "Code Interpreter Abuse": []
#       },
#       "category_scores": {
#         "Violent Crimes": 1.0,
#         "Non-Violent Crimes": 1.0,
#         "Sex Crimes": 1.0,
#         "Child Exploitation": 1.0,
#         "Defamation": 1.0,
#         "Specialized Advice": 1.0,
#         "Privacy": 1.0,
#         "Intellectual Property": 1.0,
#         "Indiscriminate Weapons": 1.0,
#         "Hate": 1.0,
#         "Self-Harm": 1.0,
#         "Sexual Content": 1.0,
#         "Elections": 1.0,
#         "Code Interpreter Abuse": 1.0
#       },
#       "metadata": {},
#       "user_message": null
#     }
#   ]
# }

# %% [markdown]
# As you can see, the first request (asking for burglary targets) has `flagged=True`, metadata indicating a `violation_type` of `S2`.  To see a list of violations, see the [Llama Guard model card](https://huggingface.co/meta-llama/Meta-Llama-Guard-2-8B) since we're are using `provider_id="llama-guard"`.  There is also a list of categories including `"Non-Violent Crimes": true`.  Finally there is a `user_message` responding with a non-answer.  These all indicate an unsafe response.
#
# In contrast, the second request ("Have a nice day!) has none of these traits, indicating that this is a safe input.
#
# Next we extend the SimpleExampleAgent to call this API on the input:

# %%
class ModerationResponseOutputBlock:
    def __init__(self, user_message):
        self.text = user_message

class ModerationResponseOutput:
    def __init__(self, user_message):
        self.type = "message"
        self.content = [ModerationResponseOutputBlock(user_message)]

class ModerationResponseObject:
    def __init__(self, result):
        self.type = "ModerationResponseObject"
        # Note that this is just passing along the refusal message from the moderations response.
        # Alternatively, you could just have a static refusal message or some other custom logic.
        self.output = [ModerationResponseOutput(result.user_message)]
        self.output_text = result.user_message

class SimpleExampleSessionWithModeration:
    def __init__(self, agent):
        self.agent = agent
        self.previous_response_id = None
    
    def create_turn(self, input):
        moderation = client.moderations.create(input=input, model=self.agent.shield_model)
        for result in moderation.results:
            if result.flagged:
                return ModerationResponseObject(result)
        response = self.agent.client.responses.create(
            model=self.agent.model,
            input=input,
            previous_response_id=self.previous_response_id,
            instructions=self.agent.instructions,
            tools=self.agent.tools
        )
        # Note that you might also want to iterate over the blocks in the response
        # and check for unsafe outputs in each of them or all of them together.
        # In this example, we just check the input, but some applications might want
        # to check the output instead or to check both.
        self.previous_response_id = response.id
        return response

class SimpleExampleAgentWithModeration:
    def __init__(self, model, shield_model, instructions, client, tools):
        self.model = model
        self.shield_model = shield_model
        self.instructions = instructions
        self.client = client
        self.tools = tools
        shields = client.shields.list()
        has_shield = any(shield.provider_resource_id == shield_model for shield in shields)
        if not has_shield:
            shield_id = f"content_safety_{shield_model}"
            client.shields.register(
                shield_id=shield_id,
                provider_id="llama-guard",
                provider_shield_id=shield_model
            )

    def create_session(self):
        return SimpleExampleSessionWithModeration(self)

# %% [markdown]
# We verify that this still works with the safe original example prompt:

# %%
simple_agent_with_moderation = SimpleExampleAgentWithModeration(
    model=LLAMA_STACK_MODEL_ID, # gpt-4o
    shield_model="openai/gpt-3.5-turbo",
    instructions=NPS_INSTRUCTIONS,
    client=client,
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "NPS",
        }
    ]
)
simple_session_with_moderation = simple_agent_with_moderation.create_session()

simple_agent_response_with_moderation1 = simple_session_with_moderation.create_turn(NPS_EXAMPLE_PROMPT)
print(simple_agent_response_with_moderation1.output_text)
# Out:
# INFO:httpx:HTTP Request: GET http://localhost:8321/v1/shields "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/moderations "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# Here are some notable parks in Rhode Island:
#
# 1. **Blackstone River Valley National Historical Park**
#    Description: The Blackstone River powered America's entry into the Age of Industry. The success of Samuel Slater's cotton spinning mill in Pawtucket, RI was instrumental in transforming the landscape of the Blackstone Valley and the United States.
#    [Visit the Website](https://www.nps.gov/blrv/index.htm)
#    Location: Rhode Island and Massachusetts
#
# 2. **Roger Williams National Memorial**
#    Description: Roger Williams founded Providence in 1636. This park recognizes his efforts and ideals regarding religious freedom.
#    [Visit the Website](https://www.nps.gov/rowi/index.htm)
#    Location: Rhode Island
#
# 3. **Touro Synagogue National Historic Site**
#    Description: Designated a National Historic Site in 1946, Touro Synagogue is one of the most historically significant Jewish buildings in America.
#    [Visit the Website](https://www.nps.gov/tosy/index.htm)
#    Location: Rhode Island
#
# 4. **Washington-Rochambeau Revolutionary Route National Historic Trail**
#    Description: This historic trail honors the route taken by Revolutionary War generals and their armies.
#    [Visit the Website](https://www.nps.gov/waro/index.htm)
#    Location: Multiple states including Rhode Island
#
# ### Upcoming Events
#
# **Blackstone River Valley National Historical Park:**
#
# - **Blackstone Canal Hike Series:**
#   Join for free hikes on Saturday mornings in January at 10:30 AM. The hikes will take place at various locations along the historic Blackstone Canal. No extra fees, but programs may be canceled due to weather. Check the park's website for updates.
#
# - **Revolutionary War Pension Files Transcription Event:**
#   Become a citizen archivist and help in transcribing Revolutionary War Pension Files. The event is co-hosted with the Upton Historical Society and will take place on January 14, 2026, from 6-8 PM at the Upton Community Center in Massachusetts. Capacity is limited, and participants should email for entry.
#
# **Roger Williams National Memorial:**
# No upcoming events were found.
#
# You might find more detailed information and updates by visiting the specific park websites or contacting them directly.

# %%
pretty_print(simple_agent_response_with_moderation1)
# Out:
# {
#   "id": "resp_dd5f816d-3279-479e-9538-3d90d2d64d1a",
#   "created_at": 1765398408,
#   "model": "openai/gpt-4o",
#   "output": [
#     {
#       "id": "mcp_list_07d13037-3bbe-423a-8f25-562acb07546c",
#       "server_label": "NPS",
#       "tools": [
#         {
#           "input_schema": {
#             "properties": {
#               "state_code": {
#                 "anyOf": [
#                   {
#                     "type": "string"
#                   },
#                   {
#                     "type": "null"
#                   }
#                 ],
#                 "default": null,
#                 "title": "State Code"
#               },
#               "park_code": {
#                 "anyOf": [
#                   {
#                     "type": "string"
#                   },
#                   {
#                     "type": "null"
#                   }
#                 ],
#                 "default": null,
#                 "title": "Park Code"
#               },
#               "query": {
#                 "anyOf": [
#                   {
#                     "type": "string"
#                   },
#                   {
#                     "type": "null"
#                   }
#                 ],
#                 "default": null,
#                 "title": "Query"
#               },
#               "limit": {
#                 "default": 10,
#                 "title": "Limit",
#                 "type": "integer"
#               }
#             },
#             "type": "object"
#           },
#           "name": "search_parks",
#           "description": "Search for national parks by state, park code, or query string.\n\nArgs:\n    state_code: Two-letter state code (e.g., 'CA', 'NY')\n    park_code: Four-letter park code (e.g., 'yell', 'acad')\n    query: Search query for park names or descriptions\n    limit: Maximum number of results to return (default: 10)\n\nReturns:\n    JSON string with park information including name, description, website, and location"
#         },
#         {
#           "input_schema": {
#             "properties": {
#               "park_code": {
#                 "title": "Park Code",
#                 "type": "string"
#               }
#             },
#             "required": [
#               "park_code"
#             ],
#             "type": "object"
#           },
#           "name": "get_park_alerts",
#           "description": "Get current alerts for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n\nReturns:\n    JSON string with current alerts for the park"
#         },
#         {
#           "input_schema": {
#             "properties": {
#               "park_code": {
#                 "title": "Park Code",
#                 "type": "string"
#               },
#               "limit": {
#                 "default": 10,
#                 "title": "Limit",
#                 "type": "integer"
#               }
#             },
#             "required": [
#               "park_code"
#             ],
#             "type": "object"
#           },
#           "name": "get_park_campgrounds",
#           "description": "Get campground information for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of campgrounds to return (default: 10)\n\nReturns:\n    JSON string with campground information including location, amenities, and fees"
#         },
#         {
#           "input_schema": {
#             "properties": {
#               "park_code": {
#                 "title": "Park Code",
#                 "type": "string"
#               },
#               "limit": {
#                 "default": 10,
#                 "title": "Limit",
#                 "type": "integer"
#               }
#             },
#             "required": [
#               "park_code"
#             ],
#             "type": "object"
#           },
#           "name": "get_park_events",
#           "description": "Get upcoming events for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of events to return (default: 10)\n\nReturns:\n    JSON string with event information including date, time, fee, and description"
#         },
#         {
#           "input_schema": {
#             "properties": {
#               "park_code": {
#                 "title": "Park Code",
#                 "type": "string"
#               },
#               "limit": {
#                 "default": 10,
#                 "title": "Limit",
#                 "type": "integer"
#               }
#             },
#             "required": [
#               "park_code"
#             ],
#             "type": "object"
#           },
#           "name": "get_visitor_centers",
#           "description": "Get visitor center information for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of visitor centers to return (default: 10)\n\nReturns:\n    JSON string with visitor center information including location, contact, and operating hours"
#         }
#       ],
#       "type": "mcp_list_tools"
#     },
#     {
#       "id": "fc_fb778750-132e-4897-bbeb-0e34cbb859cd",
#       "arguments": "{\"state_code\": \"RI\"}",
#       "name": "search_parks",
#       "server_label": "NPS",
#       "error": null,
#       "output": "{\n  \"total\": \"4\",\n  \"parks\": [\n    {\n      \"name\": \"Blackstone River Valley National Historical Park\",\n      \"code\": \"blrv\",\n      \"description\": \"The Blackstone River powered America's entry into the Age of Industry. The success of Samuel Slater's cotton spinning mill in Pawtucket, RI touched off a chain reaction that changed how people worked and where they lived. Learn how this revolution transformed the landscape of the Blackstone Valley and the United States. The Visitor Center at Old Slater Mill is closed for the winter season.\",\n      \"website\": \"https://www.nps.gov/blrv/index.htm\",\n      \"states\": \"RI,MA\",\n      \"designation\": \"National Historical Park\",\n      \"latitude\": \"41.8775792792\",\n      \"longitude\": \"-71.382433945\"\n    },\n    {\n      \"name\": \"Roger Williams National Memorial\",\n      \"code\": \"rowi\",\n      \"description\": \"\\\"I acknowledge that to molest any person, Jew or Gentile, for either professing doctrine, or practicing worship meerly religious or spiritual, is to persecute him, and such a person (whether his doctrine or practice be true or false) suffers persecution for conscience.\\\" -Roger Williams, 1644 Banished by the English and saved by the First Peoples, Roger Williams founded Providence here in 1636.\",\n      \"website\": \"https://www.nps.gov/rowi/index.htm\",\n      \"states\": \"RI\",\n      \"designation\": \"National Memorial\",\n      \"latitude\": \"41.8298955\",\n      \"longitude\": \"-71.41056665\"\n    },\n    {\n      \"name\": \"Touro Synagogue National Historic Site\",\n      \"code\": \"tosy\",\n      \"description\": \"Touro Synagogue, a building of exquisite beauty and design, steeped in history and ideals, and one of the most historically significant Jewish buildings in America, was designated a National Historic Site in 1946. Dedicated in 1763, it still serves an active congregation and each year greets over 30,000 visitors who come to see the magnificent interior and hear its remarkable story.\",\n      \"website\": \"https://www.nps.gov/tosy/index.htm\",\n      \"states\": \"RI\",\n      \"designation\": \"National Historic Site\",\n      \"latitude\": \"41.4893\",\n      \"longitude\": \"-71.3121\"\n    },\n    {\n      \"name\": \"Washington-Rochambeau Revolutionary Route National Historic Trail\",\n      \"code\": \"waro\",\n      \"description\": \"\\u201cOf the happiness I have enjoyed in our private friendship. The remembrance of which will be one of the most pleasing Circumstances of my life.\\u201d\\u2013 Comte de Rochambeau on his relationship with George Washington\",\n      \"website\": \"https://www.nps.gov/waro/index.htm\",\n      \"states\": \"MA,RI,CT,NY,NJ,PA,DE,MD,VA,DC\",\n      \"designation\": \"National Historic Trail\",\n      \"latitude\": \"40.0958204557\",\n      \"longitude\": \"-74.8563515109\"\n    }\n  ]\n}",
#       "type": "mcp_call"
#     },
#     {
#       "id": "fc_6a886354-b726-44d2-bb39-a48953f5728e",
#       "arguments": "{\"park_code\": \"blrv\"}",
#       "name": "get_park_events",
#       "server_label": "NPS",
#       "error": null,
#       "output": "{\n  \"parkCode\": \"BLRV\",\n  \"totalEvents\": 6,\n  \"events\": [\n    {\n      \"title\": \"Blackstone Canal Hike Series\",\n      \"description\": \"<p class=\\\"\\\">Join us for hikes on Saturday mornings in January at 10:30 AM. Hikes will depart from various locations along the historic Blackstone Canal on 1/3, 1/10, 1/17, and 1/24.</p>\\n<p class=\\\"\\\">All hikes are free. This series is presented in partnership with MA DCR.</p>\\n<h4 class=\\\"\\\">January 3: Blackstone River State Park</h4>\\n<p class=\\\"\\\">Meet at the Kelly House Museum, 1075 Lower River Road, Lincoln, RI</p>\\n<h4 class=\\\"\\\">January 10: Millville Lock</h4>\\n<p class=\\\"\\\">Meet at Blackstone River Greenway Parking Lot, Corner of Central Street and Hope Street, Millville, MA</p>\\n<h4 class=\\\"\\\">January 17: The Old Stanley Woolen Mills</h4>\\n<p class=\\\"\\\">Meet at Trailhead at 9 Cross Street, Uxbridge, MA</p>\\n<h4 class=\\\"\\\">January 24: Goat Hill Lock</h4>\\n<p class=\\\"\\\">Meet at River Bend Farm Visitor Center, 287 Oak Street, Uxbridge, MA</p>\\n<p class=\\\"\\\"><em class=\\\"\\\">Please note: these programs are subject to cancelation because of inclement weather. Check the park\\u2019s website and Facebook page for the latest information on whether programs have been canceled.</em></p>\",\n      \"location\": \"Meet at the Kelly House Museum, 1075 Lower River Road, Lincoln, RI\",\n      \"dateStart\": \"\",\n      \"dateEnd\": \"\",\n      \"timeStart\": \"\",\n      \"timeEnd\": \"\",\n      \"feeInfo\": \"\",\n      \"isRecurring\": false,\n      \"parkCode\": \"\"\n    },\n    {\n      \"title\": \"Blackstone Canal Hike Series\",\n      \"description\": \"<p class=\\\"\\\">Join us for hikes on Saturday mornings in January at 10:30 AM. Hikes will depart from various locations along the historic Blackstone Canal on 1/3, 1/10, 1/17, and 1/24.</p>\\n<p>\\u00a0</p>\\n<p class=\\\"\\\">All hikes are free. This series is presented in partnership with MA DCR.</p>\\n<h4>January 10: Millville Lock</h4>\\n<p>Meet at Blackstone River Greenway Parking Lot, Corner of Central Street and Hope Street, Millville, MA</p>\\n<p>\\u00a0</p>\\n<h4 class=\\\"\\\">January 17: The Old Stanley Woolen Mills</h4>\\n<p>\\u00a0</p>\\n<p class=\\\"\\\">Meet at Trailhead at 9 Cross Street, Uxbridge, MA</p>\\n<p>\\u00a0</p>\\n<h4 class=\\\"\\\">January 24: Goat Hill Lock</h4>\\n<p>\\u00a0</p>\\n<p class=\\\"\\\">Meet at River Bend Farm Visitor Center, 287 Oak Street, Uxbridge, MA</p>\\n<p>\\u00a0</p>\\n<p class=\\\"\\\"><em class=\\\"\\\">Please note: these programs are subject to cancelation because of inclement weather. Check the park\\u2019s website and Facebook page for the latest information on whether programs have been canceled.</em></p>\",\n      \"location\": \"Meet at Blackstone River Greenway Parking Lot, Corner of Central Street and Hope Street, Millville, MA\",\n      \"dateStart\": \"\",\n      \"dateEnd\": \"\",\n      \"timeStart\": \"\",\n      \"timeEnd\": \"\",\n      \"feeInfo\": \"\",\n      \"isRecurring\": false,\n      \"parkCode\": \"\"\n    },\n    {\n      \"title\": \"Revolutionary War Pension Files Transcription Event\",\n      \"description\": \"<p>In celebration of the 250th anniversary of American independence, the National Archives and the National Park Service are collaborating on a special project to transcribe Revolutionary War Pension Files of more than 80,000 of America's first veterans and their windows, containing more than 2 million documents. These records may contain valuable details about Revolutionary War veterans and their families, such as rank, unit, period of service, age, residence, date and place of marriage, and date and place of death of spouse. You may find copies of marriage or other family records, information pertaining to military activities or details about soldier's lives, along with letters, diaries, or family trees within these records. Become a citizen archivist and unlo ...
#       "type": "mcp_call"
#     },
#     {
#       "id": "fc_b38a182c-2ecc-4fc5-9a4a-251ccb4bad34",
#       "arguments": "{\"park_code\": \"rova\"}",
#       "name": "get_park_events",
#       "server_label": "NPS",
#       "error": null,
#       "output": "{\"parkCode\": \"ROVA\", \"message\": \"No upcoming events found for this park\"}",
#       "type": "mcp_call"
#     },
#     {
#       "content": [
#         {
#           "text": "Here are some notable parks in Rhode Island:\n\n1. **Blackstone River Valley National Historical Park**  \n   Description: The Blackstone River powered America's entry into the Age of Industry. The success of Samuel Slater's cotton spinning mill in Pawtucket, RI was instrumental in transforming the landscape of the Blackstone Valley and the United States.  \n   [Visit the Website](https://www.nps.gov/blrv/index.htm)  \n   Location: Rhode Island and Massachusetts\n\n2. **Roger Williams National Memorial**  \n   Description: Roger Williams founded Providence in 1636. This park recognizes his efforts and ideals regarding religious freedom.  \n   [Visit the Website](https://www.nps.gov/rowi/index.htm)  \n   Location: Rhode Island\n\n3. **Touro Synagogue National Historic Site**  \n   Description: Designated a National Historic Site in 1946, Touro Synagogue is one of the most historically significant Jewish buildings in America.  \n   [Visit the Website](https://www.nps.gov/tosy/index.htm)  \n   Location: Rhode Island\n\n4. **Washington-Rochambeau Revolutionary Route National Historic Trail**  \n   Description: This historic trail honors the route taken by Revolutionary War generals and their armies.  \n   [Visit the Website](https://www.nps.gov/waro/index.htm)  \n   Location: Multiple states including Rhode Island\n\n### Upcoming Events\n\n**Blackstone River Valley National Historical Park:**\n\n- **Blackstone Canal Hike Series:**  \n  Join for free hikes on Saturday mornings in January at 10:30 AM. The hikes will take place at various locations along the historic Blackstone Canal. No extra fees, but programs may be canceled due to weather. Check the park's website for updates.\n\n- **Revolutionary War Pension Files Transcription Event:**  \n  Become a citizen archivist and help in transcribing Revolutionary War Pension Files. The event is co-hosted with the Upton Historical Society and will take place on January 14, 2026, from 6-8 PM at the Upton Community Center in Massachusetts. Capacity is limited, and participants should email for entry.\n\n**Roger Williams National Memorial:**  \nNo upcoming events were found.\n\nYou might find more detailed information and updates by visiting the specific park websites or contacting them directly.",
#           "annotations": [],
#           "type": "output_text"
#         }
#       ],
#       "role": "assistant",
#       "id": "msg_4685eaca-9a00-49a2-a46a-77022b2b6ef6",
#       "status": "completed",
#       "type": "message"
#     }
#   ],
#   "status": "completed",
#   "error": null,
#   "instructions": "You are a helpful assistant that can answer questions about the National Parks Service.",
#   "max_tool_calls": null,
#   "object": "response",
#   "parallel_tool_calls": true,
#   "previous_response_id": null,
#   "prompt": null,
#   "temperature": null,
#   "text": {
#     "format": {
#       "description": null,
#       "name": null,
#       "schema_": null,
#       "strict": null,
#       "type": "text"
#     }
#   },
#   "tools": [
#     {
#       "server_label": "NPS",
#       "allowed_tools": null,
#       "type": "mcp"
#     }
#   ],
#   "top_p": null,
#   "truncation": null,
#   "usage": {
#     "input_tokens": 4004,
#     "output_tokens": 540,
#     "total_tokens": 4544,
#     "input_tokens_details": {
#       "cached_tokens": 0
#     },
#     "output_tokens_details": {
#       "reasoning_tokens": 0
#     }
#   }
# }

# %% [markdown]
# Next we try with the NPS_EXAMPLE_SAFETY_PROMPT (the one about burglary):

# %%
simple_agent_response_with_moderation2 = simple_session_with_moderation.create_turn(NPS_EXAMPLE_SAFETY_PROMPT)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/moderations "HTTP/1.1 200 OK"

# %% [markdown]
# The output here is our simple ModerationResponseObject with just the moderation output as you can see below:

# %%
pretty_print(simple_agent_response_with_moderation2)
# Out:
# {
#   "type": "ModerationResponseObject",
#   "output": [
#     {
#       "type": "message",
#       "content": [
#         {
#           "text": "I can't answer that. Can I help with something else?"
#         }
#       ]
#     }
#   ],
#   "output_text": "I can't answer that. Can I help with something else?"
# }

# %% [markdown]
# Notice that this example didn't include the human-in-the-loop tool approval capabilities discussed in the previous section.  You may want to combine the extensions in both of these sections and then continue to extend with all of the other advanced features you need for your application.

# %% [markdown]
# ### Using extra_body/guardrails
#
# Llama Stack also has a special non-breaking extension to the OpenAI-compatible APIs.  This lets you embed the moderation call inside the Responses API so you don't need to call it separately. To do this, you use a parameter called `extra_body` and provide a dictionary with key `guardrails` and value of a list of shield `identifier` values.  Here is an example of use (assuming you have already run `client.shields.register` as we did earlier in this notebook):

# %%
shields = client.shields.list()
first_shield_identifier = shields[0].identifier
shields
# Out:
# INFO:httpx:HTTP Request: GET http://localhost:8321/v1/shields "HTTP/1.1 200 OK"
# [Shield(identifier='content_safety', provider_id='llama-guard', params={}, provider_resource_id='openai/gpt-3.5-turbo', type='shield')]

# %%
unsafe_agent_response_using_guardrails = client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input=NPS_EXAMPLE_SAFETY_PROMPT, # This is the one about burglary above.
    instructions=NPS_INSTRUCTIONS,
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "NPS",
            "authorization": NPS_ACCESS_TOKEN,
        }
    ],
    extra_body={"guardrails": [first_shield_identifier]}, # This is the special extension to the OpenAI-compatible APIs
)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"

# %%
unsafe_agent_response_using_guardrails
# Out:
# ResponseObject(id='resp_1e14d7f7-97bb-4cbf-9dcb-f0c0d3309ff5', created_at=1765398419, model='openai/gpt-4o', output=[OutputOpenAIResponseMessageOutput(content=[OutputOpenAIResponseMessageOutputContentListOpenAIResponseOutputMessageContentOutputTextOpenAIResponseContentPartRefusalOpenAIResponseContentPartRefusal(refusal="I can't answer that. Can I help with something else? (flagged for: Non-Violent Crimes) (violation type: S2)", type='refusal')], role='assistant', id=None, status=None, type='message')], status='completed', error=None, instructions=None, max_tool_calls=None, object='response', parallel_tool_calls=True, previous_response_id=None, prompt=None, temperature=None, text=Text(format=TextFormat(description=None, name=None, schema_=None, strict=None, type='text')), tools=None, top_p=None, truncation=None, usage=None, metadata=None)

# %% [markdown]
# If you look closely at the ResponseObject above, you will see that the first entry in the `output.content` list is a dictionary with key `type` and value `refusal`.  Compare that to a "normal" responses output below:

# %%
normal_response = client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input="What is the capital of France?",
)
normal_response
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# ResponseObject(id='resp_e2e23f5b-3993-4649-a256-455c8625929a', created_at=1765398420, model='openai/gpt-4o', output=[OutputOpenAIResponseMessageOutput(content=[OutputOpenAIResponseMessageOutputContentListOpenAIResponseOutputMessageContentOutputTextOpenAIResponseContentPartRefusalOpenAIResponseOutputMessageContentOutputText(text='The capital of France is Paris.', annotations=[], type='output_text')], role='assistant', id='msg_2534dba3-4410-42e0-a9dd-1cf75bc8395d', status='completed', type='message')], status='completed', error=None, instructions=None, max_tool_calls=None, object='response', parallel_tool_calls=True, previous_response_id=None, prompt=None, temperature=None, text=Text(format=TextFormat(description=None, name=None, schema_=None, strict=None, type='text')), tools=[], top_p=None, truncation=None, usage=Usage(input_tokens=14, output_tokens=7, total_tokens=21, input_tokens_details=UsageInputTokensDetails(cached_tokens=0), output_tokens_details=UsageOutputTokensDetails(reasoning_tokens=0)), metadata=None)

# %% [markdown]
# Here you see that the first entry in the `output.content` list is a `OutputOpenAIResponseMessageContentUnionMember2` object with a `type` *field* with value `output_text`.  This complicates processing of output blocks because some of them have a `type` field and others have a dictionary with a `type` key.  This is a consequence of the fact that the `extra_body`/`guardrails` capability is a non-breaking extension to the OpenAI APIs but the actual response object classes in the Llama Stack client only cover outputs produced by the actual OpenAI APIs, so the client represents this extension information as a dictionary.

# %% [markdown]
# An advantage of the extra_body/guardrails approach is that you don't need to separately call the Moderations API before and/or after the call to Responses because it is all done for you in a single call.  One disadvantage of this approach is the added complexity in the client data structures discussed above.  Another disadvantage of course is that you no longer have access to the fine-grained control that you get from being able to make separate Moderations calls before and/or after Responses, inspect all the structured output and use it in your application.  For example, some chat UI applications might want to use different icons or colors for input moderation violations, output moderation violations, violations of different types, etc.  However, if you don't mind dealing with the data structures and you don't need all that fine-grained control, then the `extra_body` approach might be the ideal fit.  Here is how we do that in our simple example agent:

# %%
class AlternateModerationResponseOutputBlock:
    def __init__(self, user_message):
        self.text = user_message

class AlternateModerationResponseOutput:
    def __init__(self, user_message):
        self.type = "message"
        self.content = [AlternateModerationResponseOutputBlock(user_message)]

class AlternateModerationResponseObject:
    def __init__(self, user_message):
        self.type = "AlternateModerationResponseObject"
        self.output = [AlternateModerationResponseOutput(user_message)]
        self.output_text = user_message
        
class AlternateSimpleExampleSessionWithModeration:
    def __init__(self, agent):
        self.agent = agent
        self.previous_response_id = None
    
    def create_turn(self, input):
        response = self.agent.client.responses.create(
            model=self.agent.model,
            input=input,
            previous_response_id=self.previous_response_id,
            instructions=self.agent.instructions,
            tools=self.agent.tools,
            extra_body={"guardrails": [self.agent.shield_identifier]}
        )
        self.previous_response_id = response.id
        for output_block in response.output:
            if output_block.type == "message":
                for content_block in output_block.content:
                    # We need to check for a dictionary with a `type` key because the extra_body/guardrails
                    # feature returns a dictionary but other content blocks are generally objects with a `type` field.
                    if isinstance(content_block, dict) and content_block["type"] == "refusal":
                        # Note that this is just passing along the refusal message from the guardrails.
                        # Alternatively, you could just have a static refusal message or some other custom logic.
                        # Or you could just return the response object as is and let the caller decide what to do.
                        return AlternateModerationResponseObject(content_block["refusal"])
        return response

class AlternateSimpleExampleAgentWithModeration:
    def __init__(self, model, shield_model, instructions, client, tools):
        self.model = model
        self.instructions = instructions
        self.client = client
        self.tools = tools
        shields = client.shields.list()
        self.shield_identifier = None
        for shield in shields:
            if shield.provider_resource_id == shield_model:
                self.shield_identifier = shield.identifier
        if not self.shield_identifier:
            shield_id = f"content_safety_{shield_model}"
            client.shields.register(
                shield_id=shield_id,
                provider_id="llama-guard",
                provider_shield_id=shield_model
            )
            self.shield_identifier = shield_id

    def create_session(self):
        return AlternateSimpleExampleSessionWithModeration(self)

# %% [markdown]
# Once again, we first instantiate the agent and verify that a safe prompt still works as before:

# %%
client.shields.list()
# Out:
# INFO:httpx:HTTP Request: GET http://localhost:8321/v1/shields "HTTP/1.1 200 OK"
# [Shield(identifier='content_safety', provider_id='llama-guard', params={}, provider_resource_id='openai/gpt-3.5-turbo', type='shield')]

# %%
alt_simple_agent_with_moderation = AlternateSimpleExampleAgentWithModeration(
    model=LLAMA_STACK_MODEL_ID, # gpt-4o
    shield_model="openai/gpt-3.5-turbo",
    instructions=NPS_INSTRUCTIONS,
    client=client,
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "NPS",
        }
    ]
)
# Out:
# INFO:httpx:HTTP Request: GET http://localhost:8321/v1/shields "HTTP/1.1 200 OK"

# %%
alt_simple_agent_with_moderation.shield_identifier
# Out:
# 'content_safety'

# %%
alt_simple_session_with_moderation = alt_simple_agent_with_moderation.create_session()
alt_simple_agent_response_with_moderation1 = alt_simple_session_with_moderation.create_turn("Hello!")
print(alt_simple_agent_response_with_moderation1.output_text)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# Hi there! How can I assist you today?

# %% [markdown]
# Then we test with the unsafe (burglary) example:

# %%
alt_simple_agent_response_with_moderation2 = alt_simple_session_with_moderation.create_turn(NPS_EXAMPLE_SAFETY_PROMPT)
print(alt_simple_agent_response_with_moderation2.output_text)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"

# %%
pretty_print(alt_simple_agent_response_with_moderation2)
# Out:
# {
#   "id": "resp_14de8b40-4647-4211-8781-b5c9817cd666",
#   "created_at": 1765398428,
#   "model": "openai/gpt-4o",
#   "output": [
#     {
#       "content": [
#         {
#           "refusal": "I can't answer that. Can I help with something else? (flagged for: Non-Violent Crimes) (violation type: S2)",
#           "type": "refusal"
#         }
#       ],
#       "role": "assistant",
#       "id": null,
#       "status": null,
#       "type": "message"
#     }
#   ],
#   "status": "completed",
#   "error": null,
#   "instructions": null,
#   "max_tool_calls": null,
#   "object": "response",
#   "parallel_tool_calls": true,
#   "previous_response_id": null,
#   "prompt": null,
#   "temperature": null,
#   "text": {
#     "format": {
#       "description": null,
#       "name": null,
#       "schema_": null,
#       "strict": null,
#       "type": "text"
#     }
#   },
#   "tools": null,
#   "top_p": null,
#   "truncation": null,
#   "usage": null
# }

# %% [markdown]
# Notice that this is returning our custom "AlternateModerationResponseObject" because the moderation flagged this output.

# %% [markdown]
# This notebook has presented two alternative approaches to using guardrails models:
#
# - Calling the Moderations API on the inputs and outputs of the Responses call lets you control the guardrails yourself at the cost of having to make additional API calls.
# - Including `extra_body={"guardrails": [shield_id]}` in the Responses call gets Llama Stack to run the guardrails for you at the cost of less control and some added complexity in the client data structures.
#
# Developers should consider the advantages and disadvantages of each option and choose the one that is best suited to their application.

# %% [markdown]
# ## ReAct Agents
#
# The Llama Stack Python Client has a client-side [ReAct Agent](https://github.com/llamastack/llama-stack-client-python/blob/main/src/llama_stack_client/lib/agents/react/agent.py) construct.  This construct still works.  It operates by listing the tools and formulating a text prompt that combines the user request, system instructions, and tool list into one big text prompt.  Those system instructions direct the model to take in observations and output thoughts before selecting an action, which can improve accuracy because it forces the model to split up the challenging process of identifying the right tool and parameter values into multiple simpler steps.  The accuracy benefits come at a cost of longer latency and higher token generation charges since outputting thoughts takes time and tokens.  For some challenging, high-value tasks the improved accuracy is worth the added time and cost.  For more details about ReAct see [ReAct: Synergizing Reasoning and Acting in Language Models](https://arxiv.org/abs/2210.03629).
#
# ReAct was a revolutionary technique in 2022 when the paper was first published, but it is less relevant today because the lessons from ReAct have been expanded upon and incorporated into other parts of the technology stack.  In particular, some key elements and where they have wound up are:
#
# - *Listing tools with formal input schemas*: In 2022, this needed to be done inside a single block of text because generative AI models were trained to take in a single block of text and output a single block of text.  However, modern "chat completion" models are generally trained to take a formal structure in which there are pre-defined separators and schemas for session history, tools, etc.  Of course, it is still *possible* to just lump all that info into a plain text blob like people did in 2022, but since the models are tuned to use the formal structure, it seems likely that you will get better results more often using that structure.  The way to use that structure is just to use the appropriate parameters in the Responses or Chat Completions APIs.  For example, if you list your tools in the `tools` parameter of Responses, a well-trained chat completion model is more likely to select the right tool more often than if you just describe them in plain text in the user message.
# - *Outputting thoughts before deciding how to ReAct*: Recent "reasoning" models are trained specifically to do this using a formal structure.  For example, gpt-oss uses a format called [Harmony](https://cookbook.openai.com/articles/openai-harmony) in which the models output their reasoning before selecting tools and/or providing response text to end users for exactly this reason.
#
# So if you are working with a modern "reasoning" model and an API that has formal structures for listing tools and outputting thoughts, then you would normally expect that your model and infrastructure are already providing the core benefits of ReAct.  On the other hand, if you are just using a "chat completion" model that is trained for tool selection but isn't explicitly trained to output thoughts before selecting a tool, then some sort of hybrid where you use a ReAct style prompt to encourage outputting thoughts before selecting a tool might be effective.

# %% [markdown]
# ### How the existing ReAct agents in the Llama Stack Python client work
#
# Before getting into such a hybrid approach, let's take a look at how the ReAct agents in the Llama Stack Python client work now.  First we will register an MCP server and then list all the tools.

# %%
from llama_stack_client.types.toolgroup_register_params import McpEndpoint

client.toolgroups.register(
    toolgroup_id="mcp::nps",
    provider_id="model-context-protocol",
    mcp_endpoint=McpEndpoint(uri=NPS_MCP_URL),
)
# Out:
# /var/folders/2b/b5b46qw54yd7c62llcrq5qww0000gn/T/ipykernel_90210/4080764528.py:3: DeprecationWarning: deprecated
#   client.toolgroups.register(
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/toolgroups "HTTP/1.1 200 OK"

# %%
tool_defs = client.tools.list(toolgroup_id="mcp::nps")
tool_defs
# Out:
# INFO:httpx:HTTP Request: GET http://localhost:8321/v1/tools?toolgroup_id=mcp%3A%3Anps "HTTP/1.1 200 OK"
# [ToolDef(name='search_parks', description="Search for national parks by state, park code, or query string.\n\nArgs:\n    state_code: Two-letter state code (e.g., 'CA', 'NY')\n    park_code: Four-letter park code (e.g., 'yell', 'acad')\n    query: Search query for park names or descriptions\n    limit: Maximum number of results to return (default: 10)\n\nReturns:\n    JSON string with park information including name, description, website, and location", input_schema={'properties': {'state_code': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None, 'title': 'State Code'}, 'park_code': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None, 'title': 'Park Code'}, 'query': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'default': None, 'title': 'Query'}, 'limit': {'default': 10, 'title': 'Limit', 'type': 'integer'}}, 'type': 'object'}, metadata={'endpoint': 'http://localhost:3005/sse/'}, output_schema={'properties': {'result': {'title': 'Result', 'type': 'string'}}, 'required': ['result'], 'title': '_WrappedResult', 'type': 'object', 'x-fastmcp-wrap-result': True}, toolgroup_id='mcp::nps'),
#  ToolDef(name='get_park_alerts', description="Get current alerts for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n\nReturns:\n    JSON string with current alerts for the park", input_schema={'properties': {'park_code': {'title': 'Park Code', 'type': 'string'}}, 'required': ['park_code'], 'type': 'object'}, metadata={'endpoint': 'http://localhost:3005/sse/'}, output_schema={'properties': {'result': {'title': 'Result', 'type': 'string'}}, 'required': ['result'], 'title': '_WrappedResult', 'type': 'object', 'x-fastmcp-wrap-result': True}, toolgroup_id='mcp::nps'),
#  ToolDef(name='get_park_campgrounds', description="Get campground information for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of campgrounds to return (default: 10)\n\nReturns:\n    JSON string with campground information including location, amenities, and fees", input_schema={'properties': {'park_code': {'title': 'Park Code', 'type': 'string'}, 'limit': {'default': 10, 'title': 'Limit', 'type': 'integer'}}, 'required': ['park_code'], 'type': 'object'}, metadata={'endpoint': 'http://localhost:3005/sse/'}, output_schema={'properties': {'result': {'title': 'Result', 'type': 'string'}}, 'required': ['result'], 'title': '_WrappedResult', 'type': 'object', 'x-fastmcp-wrap-result': True}, toolgroup_id='mcp::nps'),
#  ToolDef(name='get_park_events', description="Get upcoming events for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of events to return (default: 10)\n\nReturns:\n    JSON string with event information including date, time, fee, and description", input_schema={'properties': {'park_code': {'title': 'Park Code', 'type': 'string'}, 'limit': {'default': 10, 'title': 'Limit', 'type': 'integer'}}, 'required': ['park_code'], 'type': 'object'}, metadata={'endpoint': 'http://localhost:3005/sse/'}, output_schema={'properties': {'result': {'title': 'Result', 'type': 'string'}}, 'required': ['result'], 'title': '_WrappedResult', 'type': 'object', 'x-fastmcp-wrap-result': True}, toolgroup_id='mcp::nps'),
#  ToolDef(name='get_visitor_centers', description="Get visitor center information for a specific national park.\n\nArgs:\n    park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')\n    limit: Maximum number of visitor centers to return (default: 10)\n\nReturns:\n    JSON string with visitor center information including location, contact, and operating hours", input_schema={'properties': {'park_code': {'title': 'Park Code', 'type': 'string'}, 'limit': {'default': 10, 'title': 'Limit', 'type': 'integer'}}, 'required': ['park_code'], 'type': 'object'}, metadata={'endpoint': 'http://localhost:3005/sse/'}, output_schema={'properties': {'result': {'title': 'Result', 'type': 'string'}}, 'required': ['result'], 'title': '_WrappedResult', 'type': 'object', 'x-fastmcp-wrap-result': True}, toolgroup_id='mcp::nps')]

# %% [markdown]
# Above are the tools from the MCP server (`search_parks`, etc.)  The ReAct prompt generator takes these tools in the form of dictionary objects, so we extract those:

# %%
tool_def_dictionary_objects = [x.__dict__ for x in tool_defs]

# %% [markdown]
# and then we call the prompt generator to produce a prompt using these tool definitions:

# %%
from llama_stack_client.lib.agents.react.agent import get_default_react_instructions
print(get_default_react_instructions(tool_def_dictionary_objects))
# Out:
# You are an expert assistant who can solve any task using tool calls. You will be given a task to solve as best you can.
# To do so, you have been given access to the following tools: search_parks, get_park_alerts, get_park_campgrounds, get_park_events, get_visitor_centers
#
# You must always respond in the following JSON format:
# {
#     "thought": $THOUGHT_PROCESS,
#     "action": {
#         "tool_name": $TOOL_NAME,
#         "tool_params": $TOOL_PARAMS
#     },
#     "answer": $ANSWER
# }
#
# Specifically, this json should have a `thought` key, a `action` key and an `answer` key.
#
# The `action` key should specify the $TOOL_NAME the name of the tool to use and the `tool_params` key should specify the parameters key as input to the tool.
#
# Make sure to have the $TOOL_PARAMS as a list of dictionaries in the right format for the tool you are using, and do not put variable names as input if you can find the right values.
#
# You should always think about one action to take, and have the `thought` key contain your thought process about this action.
# If the tool responds, the tool will return an observation containing result of the action.
# ... (this Thought/Action/Observation can repeat N times, you should take several steps when needed. The action key must only use a SINGLE tool at a time.)
#
# You can use the result of the previous action as input for the next action.
# The observation will always be the response from calling the tool: it can represent a file, like "image_1.jpg". You do not need to generate them, it will be provided to you.
# Then you can use it as input for the next action. You can do it for instance as follows:
#
# Observation: "image_1.jpg"
# {
#     "thought": "I need to transform the image that I received in the previous observation to make it green.",
#     "action": {
#         "tool_name": "image_transformer",
#         "tool_params": [{"name": "image"}, {"value": "image_1.jpg"}]
#     },
#     "answer": null
# }
#
#
# To provide the final answer to the task, use the `answer` key. It is the only way to complete the task, else you will be stuck on a loop. So your final output should look like this:
# Observation: "your observation"
#
# {
#     "thought": "you thought process",
#     "action": null,
#     "answer": "insert your final answer here"
# }
#
# Here are a few examples using notional tools:
# ---
# Task: "Generate an image of the oldest person in this document."
#
# Your Response:
# {
#     "thought": "I will proceed step by step and use the following tools: `document_qa` to find the oldest person in the document, then `image_generator` to generate an image according to the answer.",
#     "action": {
#         "tool_name": "document_qa",
#         "tool_params": [{"name": "document"}, {"value": "document.pdf"}, {"name": "question"}, {"value": "Who is the oldest person mentioned?"}]
#     },
#     "answer": null
# }
#
# Your Observation: "The oldest person in the document is John Doe, a 55 year old lumberjack living in Newfoundland."
#
# Your Response:
# {
#     "thought": "I will now generate an image showcasing the oldest person.",
#     "action": {
#         "tool_name": "image_generator",
#         "tool_params": [{"name": "prompt"}, {"value": "A portrait of John Doe, a 55-year-old man living in Canada."}]
#     },
#     "answer": null
# }
# Your Observation: "image.png"
#
# {
#     "thought": "I will now return the generated image.",
#     "action": null,
#     "answer": "image.png"
# }
#
# ---
# Task: "What is the result of the following operation: 5 + 3 + 1294.678?"
#
# Your Response:
# {
#     "thought": "I will use python code evaluator to compute the result of the operation and then return the final answer using the `final_answer` tool",
#     "action": {
#         "tool_name": "python_interpreter",
#         "tool_params": [{"name": "code"}, {"value": "5 + 3 + 1294.678"}]
#     },
#     "answer": null
# }
# Your Observation: 1302.678
#
# {
#     "thought": "Now that I know the result, I will now return it.",
#     "action": null,
#     "answer": 1302.678
# }
#
# ---
# Task: "Which city has the highest population , Guangzhou or Shanghai?"
#
# Your Response:
# {
#     "thought": "I need to get the populations for both cities and compare them: I will use the tool `search` to get the population of both cities.",
#     "action": {
#         "tool_name": "search",
#         "tool_params": [{"name": "query"}, {"value": "Population Guangzhou"}]
#     },
#     "answer": null
# }
# Your Observation: ['Guangzhou has a population of 15 million inhabitants as of 2021.']
#
# Your Response:
# {
#     "thought": "Now let's get the population of Shanghai using the tool 'search'.",
#     "action": {
#         "tool_name": "search",
#         "tool_params": [{"name": "query"}, {"value": "Population Shanghai"}]
#     },
#     "answer": null
# }
# Your Observation: "26 million (2019)"
#
# Your Response:
# {
#     "thought": "Now I know that Shanghai has a larger population. Let's return the result.",
#     "action": null,
#     "answer": "Shanghai"
# }
#
# Above example were using notional tools that might not exist for you. You only have access to these tools:
# - search_parks: Search for national parks by state, park code, or query string.
#
# Args:
#     state_code: Two-letter state code (e.g., 'CA', 'NY')
#     park_code: Four-letter park code (e.g., 'yell', 'acad')
#     query: Search query for park names or descriptions
#     limit: Maximum number of results to return (default: 10)
#
# Returns:
#     JSON string with park information including name, description, website, and location
# - get_park_alerts: Get current alerts for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#
# Returns:
#     JSON string with current alerts for the park
# - get_park_campgrounds: Get campground information for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of campgrounds to return (default: 10)
#
# Returns:
#     JSON string with campground information including location, amenities, and fees
# - get_park_events: Get upcoming events for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of events to return (default: 10)
#
# Returns:
#     JSON string with event information including date, time, fee, and description
# - get_visitor_centers: Get visitor center information for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of visitor centers to return (default: 10)
#
# Returns:
#     JSON string with visitor center information including location, contact, and operating hours
#
# Here are the rules you should always follow to solve your task:
# 1. ALWAYS answer in the JSON format with keys "thought", "action", "answer", else you will fail.
# 2. Always use the right arguments for the tools. Never use variable names in the 'tool_params' field, use the value instead.
# 3. Call a tool only when needed: do not call the search agent if you do not need information, try to solve the task yourself.
# 4. Never re-do a tool call that you previously did with the exact same parameters.
# 5. Observations will be provided to you, no need to generate them
#
# Now Begin! If you solve the task correctly, you will receive a reward of $1,000,000.

# %% [markdown]
# As you can see, there are a few parts to this prompt:
#
# 1. It explains the output format to produce including how to list selected tools and their parameter values.
# 2. It tells the model to always take exactly one action on each turn.
# 3. It provides the model with a bunch of examples of the desired output format ("few-shot prompting").
# 4. It says "Above example were using notional tools that might not exist for you. You only have access to these tools:"
# 5. Then it lists the actual MCP tools and the arguments that they take in a semi-formal notation.
# 6. Then it lists a set of general rules such as not re-doing a tool with the same parameters.
# 7. Finally, it offers the model a reward of $1,000,000 if the model succeeds.

# %% [markdown]
# The offer of a reward is not part of the original ReAct paper, but it became popular around the same time because there were some anecdotes about it being effective.  Late 2022 through early 2023 were an extraordinarily peculiar time in the history of AI.  It seems not inconceivable it could be effective if the training data it is exposed to includes many examples of people offering a reward for answering a question followed by extraordinarily thoughtful, high quality answers.  In that case, the model pre-training could have learned this statistical trend and thus be more likely to produce extraordinarily thoughtful, high quality answers following such a prompt.  On the other hand, there doesn't seem to be substantial evidence that this actually works and it does add to the length of the input, driving up compute costs and latency.  So it is not included in the prompt for the "ReAct-inspired agentic reasoning for chat completions models using the Responses API" section later in this notebook, but feel free to try adding it and see for yourself if it helps.

# %% [markdown]
# ### Using the existing ReAct agents in the Llama Stack Python client

# %% [markdown]
# Before proposing an alternative, this notebook provides an example of how to use the existing ReAct agent construct in the Python client, which does still work in the current version of Llama Stack:

# %%
from llama_stack_client.lib.agents.react.agent import ReActAgent
react_agent = ReActAgent(
    model=LLAMA_STACK_MODEL_ID,
    instructions=NPS_INSTRUCTIONS,
    client=client,
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "NPS",
        }
    ]
)

# %%
session_id = agent.create_session(f"nps_react_session-{uuid.uuid4().hex}")

agent_response1 = agent.create_turn(
    messages=[{"role": "user", "content": NPS_EXAMPLE_PROMPT}],
    session_id=session_id,
    stream=False,
)
print(agent_response1.output_text)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# [{'type': 'mcp', 'server_url': 'http://localhost:3005/sse/', 'server_label': 'mcp::nps', 'headers': {}, 'authorization': 'frog'}]
# Rhode Island is home to several national parks. Here are some of the prominent ones:
#
# 1. **Blackstone River Valley National Historical Park**
#    - **Description**: This park highlights the Blackstone River's role in powering America's entry into the Age of Industry, starting with Samuel Slater's cotton spinning mill in Pawtucket, RI.
#    - **Website**: [Visit Blackstone River Valley](https://www.nps.gov/blrv/index.htm)
#    - **Events**:
#      - **Blackstone Canal Hike Series**: Ongoing free hikes on Saturday mornings across various locations along the historic Blackstone Canal.
#      - **Revolutionary War Pension Files Transcription Event**: Join efforts to transcribe historical pension files at community centers.
#
# 2. **Roger Williams National Memorial**
#    - **Description**: Roger Williams founded Providence in 1636 as a refuge for those persecuted for their beliefs.
#    - **Website**: [Visit Roger Williams Memorial](https://www.nps.gov/rowi/index.htm)
#    - **Events**:
#      - **Visitor Center Open**: Visitors can learn about Roger Williams' life and legacy through films and exhibits at the Visitor Center.
#
# 3. **Touro Synagogue National Historic Site**
#    - **Description**: Designated a National Historic Site in 1946, Touro Synagogue is one of America's most historically significant Jewish buildings.
#    - **Website**: [Visit Touro Synagogue](https://www.nps.gov/tosy/index.htm)
#
# 4. **Washington-Rochambeau Revolutionary Route National Historic Trail**
#    - **Description**: This trail marks the route used by the allied French and American armies during the Revolutionary War.
#    - **Website**: [Visit the Trail](https://www.nps.gov/waro/index.htm)
#
# These parks not only offer a chance to appreciate Rhode Island's natural beauty but also its rich historical significance.

# %% [markdown]
# On this simple example query, it seems to get comparable results to the results you get from calling Responses directly (see the earlier "Equivalent Responses API Example" section for more details).  The ReAct agent is instructing the model to output thoughts before acting which potentially makes it more effective.  On the other hand, pushing tool descriptions into the text of the prompt (instead of using the tool-list structure that the model is trained to process) potentially makes it less effective.  So either might be more effective for your use cases.  The Responses API is a core element of the Llama Stack strategy which focuses mainly on compatibility with the de facto industry "standard" of the OpenAI APIs.  In contrast, the ReAct agent is left over from an older strategy for Llama Stack and thus seems unlikely to undergo substantial improvement in the future.
#
# The next section proposes an alternative based on the Responses API that preserves some of the benefits of ReAct while also benefitting from some of the power of more modern chat completions models that are trained to handle structured inputs.

# %% [markdown]
# ## Using files in Responses API

# %% [markdown]
# Sometimes when you create an agent you want to set it up with a whole collection of content to use for all of its queries.  Those cases are well handled by RAG via the file_search tool.  However, in other cases users might want to attach a specific file to a message so they can ask questions about that file.  In those cases, instead of setting up a vector database for that file, you can simply attach it to the responses request directly.  Here is an example of how to do that.

# %%
import requests
from pathlib import Path

# Download a sample PDF for demonstration
def download_sample_pdf(url: str, filename: str) -> str:
    """Download a PDF from URL and save it locally"""
    print(f"Downloading PDF from: {url}")
    response = requests.get(url)
    response.raise_for_status()
    
    filepath = Path(filename)
    with open(filepath, 'wb') as f:
        f.write(response.content)
    
    print(f"PDF saved as: {filepath}")
    return str(filepath)

pdf_url = "https://www.nps.gov/npgallery/GetAsset/257b1284-d776-43d5-9a8f-863023a2e520"
pdf_path = download_sample_pdf(pdf_url, "tr_park.pdf")
pdf_title = "Theodore Roosevelt National Park"
# Out:
# Downloading PDF from: https://www.nps.gov/npgallery/GetAsset/257b1284-d776-43d5-9a8f-863023a2e520
# PDF saved as: tr_park.pdf

# %%
# Here is a sample prompt that we will use for the file attachment example.
SAMPLE_PROMPT_FOR_FILE_EXAMPLE = "What is the first quote from Theodore Roosevelt in this brochure?"

# %%
import uuid
from pathlib import Path

file_create_response = client.files.create(file=Path(pdf_path), purpose="assistants")
file_id = file_create_response.id
file_id
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/files "HTTP/1.1 200 OK"
# 'file-ac37b6a1ac6b4de99f940a5e41b15f1a'

# %%
file_example_response1 = client.responses.create(
    model=LLAMA_STACK_MODEL_ID, #"gpt-4o",
    input=[
        {
            "role": "user",
            "content": [
                {
                    "type": "input_file",
                    "file_id": file_id,
                },
                {
                    "type": "input_text",
                    "text": SAMPLE_PROMPT_FOR_FILE_EXAMPLE,
                },
            ]
        }
    ],
    instructions=NPS_INSTRUCTIONS,
    # We don't really need the tools for this example, but we're making them available
    # because we're showing how an agent can decide whether to answer from content,
    # use tools, or a mix of both.
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "NPS",
            "requires_approval": False,
            "authorization": NPS_ACCESS_TOKEN,
        }
    ]
)
print_response(file_example_response1)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# ID: resp_ec12d882-4d5d-4b04-b8c1-3d4ff3ee05f2
# Status: completed
# Model: openai/gpt-4o
# Created at: 1765398439
# Output items: 2
#
# --- Output Item 1 ---
# Output type: mcp_list_tools
#
# 🔧 MCP Server: NPS
#    ID: mcp_list_5819a8bd-39b8-4b15-bf22-439d87229eb5
#    Available Tools: 5
# ================================================================================
#
# 1. search_parks
#    Description: Search for national parks by state, park code, or query string.
#
# Args:
#     state_code: Two-letter state code (e.g., 'CA', 'NY')
#     park_code: Four-letter park code (e.g., 'yell', 'acad')
#     query: Search query for park names or descriptions
#     limit: Maximum number of results to return (default: 10)
#
# Returns:
#     JSON string with park information including name, description, website, and location
#    Parameters:
#      • state_code (unknown) (optional)
#        No description
#      • park_code (unknown) (optional)
#        No description
#      • query (unknown) (optional)
#        No description
#      • limit (integer) (optional)
#        No description
# ----------------------------------------
#
# 2. get_park_alerts
#    Description: Get current alerts for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#
# Returns:
#     JSON string with current alerts for the park
#    Parameters:
#      • park_code (string) (required)
#        No description
# ----------------------------------------
#
# 3. get_park_campgrounds
#    Description: Get campground information for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of campgrounds to return (default: 10)
#
# Returns:
#     JSON string with campground information including location, amenities, and fees
#    Parameters:
#      • park_code (string) (required)
#        No description
#      • limit (integer) (optional)
#        No description
# ----------------------------------------
#
# 4. get_park_events
#    Description: Get upcoming events for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of events to return (default: 10)
#
# Returns:
#     JSON string with event information including date, time, fee, and description
#    Parameters:
#      • park_code (string) (required)
#        No description
#      • limit (integer) (optional)
#        No description
# ----------------------------------------
#
# 5. get_visitor_centers
#    Description: Get visitor center information for a specific national park.
#
# Args:
#     park_code: Four-letter park code (e.g., 'yell', 'acad', 'grca')
#     limit: Maximum number of visitor centers to return (default: 10)
#
# Returns:
#     JSON string with visitor center information including location, contact, and operating hours
#    Parameters:
#      • park_code (string) (required)
#        No description
#      • limit (integer) (optional)
#        No description
#
# --- Output Item 2 ---
# Output type: message
# Response content: The first quote from Theodore Roosevelt in the brochure is:
#
# "I have always said I never would have been President if it had not been for my experiences in North Dakota." —Theodore Roosevelt, 1918

# %% [markdown]
# As you can see above, it does first list all the tools in the MCP server to see what's available to it, but it doesn't call any of them because they are not relevant to this query.  Instead, it correctly answers with the first quote in the brochure.  You can verify this if you look in the upper left of page one of the brochure if you open the PDF.

# %%
vector_store_name= f"vec_{str(uuid.uuid4())[0:8]}"
vector_store = client.vector_stores.create(name=vector_store_name)
vector_store_id = vector_store.id

file_ingest_response = client.vector_stores.files.create(
    vector_store_id=vector_store_id,
    file_id=file_create_response.id,
)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/vector_stores "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/vector_stores/vs_d8bbd82b-e9ed-4f61-baa4-8e0017e9ce8c/files "HTTP/1.1 200 OK"

# %% [markdown]
# ## ReAct-style agentic reasoning for chat completions models using the Responses API
#
# If you are using a "reasoning" model such as gpt-oss or gpt-4o or gpt-5 or Claude Sonnet 4.5, then the models are already trained to output thoughts before selecting actions, so there isn't really a need to explicitly prompt the model to do so -- just make sure that you are enabling the reasoning mode and then everything you might have wanted from ReAct is already covered using structures that the model is specifically trained to handle.  Conversely, if you are using a model that is only pre-trained and instruction-tuned but without a formal chat completion template, then you probably want to use something like the original ReAct capability described above.  However, many models fall in between these extremes: they are trained to recognize specific structures for a chat-completions API including both session history and tool calling, but they are not explicitly trained to output reasoning traces.  For models of this sort, you want to use those API structures for chaining messages together and telling the model what tools are available.  Thus an ideal fit might be a compromise solution like the one below:

# %%
REACT_STYLE_SYSTEM_INSTRUCTIONS = """
You are an expert assistant who can solve any task using tool calls. You will be given a task to solve as best you can.

You can use the result of the previous action as input for the next action.
The observation will always be the response from calling the tool: it can represent a file, like "image_1.jpg". You do not need to generate them, it will be provided to you. 
Then you can use it as input for the next action. You can do it for instance as follows:

Here are the rules you should always follow to solve your task:
1. Always use the right arguments for tools. Never use variable names in tool parameters, use the value instead.
2. Call a tool only when needed: do not call a tool if you do not need information, try to solve the task yourself.
3. Never re-do a tool call that you previously did with the exact same parameters.
"""

REACT_STYLE_THINK_PROMPT_TEMPLATE = """
An AI agent has been given a request from a user.  It has access to the specified tools.
Think about what that AI agent should do next.  That might include using a tool or it
might involve solving the task without using a tool.  Do not output any text other than
your thoughts about what the agent should do next.

Here is the user request:

{user_request}
"""

REACT_STYLE_ACT_PROMPT_TEMPLATE = """
You are an AI agent that has been given a request from a user.  There are some existing
thoughts for you to consider.  You should either produce a final response or select
tools to call.

Here is the user request:

{user_request}
"""

# %%
class ReActStyleSimpleExampleSession:
    def __init__(self, agent):
        self.agent = agent
        self.previous_response_id = None
    
    def create_turn(self, input):
        # Thinking phase
        response = self.agent.client.responses.create(
            model=self.agent.model,
            input=REACT_STYLE_THINK_PROMPT_TEMPLATE.format(user_request=input),
            previous_response_id=self.previous_response_id,
            instructions=REACT_STYLE_SYSTEM_INSTRUCTIONS,
            tools=self.agent.tools,
            # In the Thinking phase, we don't want the model to output anything other than the thoughts.
            # So it shouldn't actually select tools, it should just explain why it might or might not want to use a tool.

            # This parameter is not supported in the current version of the Llama Stack,
            # but you should uncomment it if you are using a future version that does support it.
            #tool_choice="none"
        )
        self.previous_response_id = response.id

        # For demo purposes, we will print the response from the thinking phase.
        print(f"Thinking phase response:")
        print(response.output_text)

        # Acting phase
        response = self.agent.client.responses.create(
            model=self.agent.model,
            input=REACT_STYLE_ACT_PROMPT_TEMPLATE.format(user_request=input),
            # Note that we are using the previous response id from the thinking phase
            # as the previous response id for the acting phase.  This allows the
            # acting phase to use the result of the thinking phase as input.
            previous_response_id=self.previous_response_id,
            instructions=REACT_STYLE_SYSTEM_INSTRUCTIONS,
            tools=self.agent.tools,
        )
        self.previous_response_id = response.id
        return response

class ReActStyleSimpleExampleAgent:
    def __init__(self, model, client, tools):
        self.model = model
        self.client = client
        self.tools = tools

    def create_session(self):
        return ReActStyleSimpleExampleSession(self)

# %% [markdown]
# Now we instantiate this agent and try it out:

# %%
simple_react_style_agent = ReActStyleSimpleExampleAgent(
    model=LLAMA_STACK_MODEL_ID,
    client=client,
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "NPS",
        }
    ]
)
simple_react_style_session = simple_react_style_agent.create_session()

simple_react_style_agent_response1 = simple_react_style_session.create_turn(NPS_EXAMPLE_PROMPT)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# Thinking phase response:
# The AI agent needs to gather information about parks in Rhode Island and check for any upcoming events at these parks. To accomplish this, the agent should first search for national parks in Rhode Island using the `functions.search_parks` tool and then, for each park found, use the `functions.get_park_events` tool to retrieve information about upcoming events. These steps can be done sequentially, first searching for parks, then checking events for each one.
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"

# %% [markdown]
# As you can see above, the thinking phase response includes an overall plan for how to satisfy the requirement.  That plan is then available as an input for the next step.  This can be helpful to a model for the same reason it can be helpful for a human doing a challenging task to first have an abstract end-to-end plan before starting to act: coming up with an outline and filling in the details are both challenging tasks so trying to do them at the same time can be harder than doing each separately.

# %%
print(simple_react_style_agent_response1.output_text)
# Out:
# Here are some parks in Rhode Island and their upcoming events:
#
# 1. **Blackstone River Valley National Historical Park**
#     - **Description**: The park showcases America's entry into the Age of Industry, featuring the success of Samuel Slater's cotton spinning mill.
#     - **Website**: [Visit Site](https://www.nps.gov/blrv/index.htm)
#     - **Upcoming Events**:
#         - **Blackstone Canal Hike Series**: Join free hikes on Saturday mornings in January at 10:30 AM, departing from various locations along the historic Blackstone Canal.
#         - **Revolutionary War Pension Files Transcription Event**: A collaborative project to transcribe Revolutionary War Pension Files. Next event on January 28, 2026, in the Sutton Senior Center.
#
# 2. **Roger Williams National Memorial**
#     - **Description**: Learn about Roger Williams' life and legacy. He founded Providence in 1636 after being banished by the English and saved by the First Peoples.
#     - **Website**: [Visit Site](https://www.nps.gov/rowi/index.htm)
#     - **Upcoming Events**:
#         - **Visitor Center Open**: Explore exhibits and watch a short film about Roger Williams with help from park rangers and volunteers.
#
# 3. **Touro Synagogue National Historic Site**
#     - **Description**: This site is one of the most historically significant Jewish buildings in America and serves as an active congregation.
#     - **Website**: [Visit Site](https://www.nps.gov/tosy/index.htm)
#     - **Upcoming Events**: No upcoming events found.
#
# 4. **Washington-Rochambeau Revolutionary Route National Historic Trail**
#     - **Description**: A trail steeped in historical significance, highlighting the friendship of Comte de Rochambeau and George Washington.
#     - **Website**: [Visit Site](https://www.nps.gov/waro/index.htm)
#     - **Upcoming Events**: No upcoming events found.
#
# Feel free to explore each park's website for more details on locations and activities!

# %% [markdown]
# As you can see, we still get the same (correct) behavior from this example.  For more challenging examples or less powerful models, you might see higher quality (but slower and more expensive) results from this approach.
#
# As in the earlier examples, you can combine this enhancement with other enhancements (human-in-the-loop tool approval, model safety, etc.) to develop an agent object that meets your needs.  Alternatively, you can just call the Responses API in the ways shown here without having a container object. These are just some examples to help you get started.

# %% [markdown]
# ## Authored multi-step agentic flows
#
# Let's take the same Responses call from earlier, but try it with a more challenging example:

# %%
NPS_MORE_CHALLENGING_EXAMPLE_PROMPT = "What's up in Rhode Island?"
(NPS_EXAMPLE_PROMPT, NPS_MORE_CHALLENGING_EXAMPLE_PROMPT)
# Out:
# ('Tell me about some parks in Rhode Island, and let me know if there are any upcoming events at them.',
#  "What's up in Rhode Island?")

# %% [markdown]
# These two queries are essentially asking for the same information, but the latter is a bit vague and imprecise which makes it more challenging for a language model.  If we try it with our existing Responses call we see:

# %%
challenging_response = client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input=NPS_MORE_CHALLENGING_EXAMPLE_PROMPT,
    instructions=NPS_INSTRUCTIONS,
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "NPS",
            "authorization": NPS_ACCESS_TOKEN,
        }
    ]
)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"

# %%
print(challenging_response.output_text)
# Out:
# Rhode Island is home to several notable national sites and trails. Here's a brief overview of each:
#
# 1. **[Blackstone River Valley National Historical Park](https://www.nps.gov/blrv/index.htm)**
#    - **Description**: This park highlights the Blackstone River's role in America's industrial revolution. The success of Samuel Slater's cotton spinning mill in Pawtucket spurred a transformation in the Blackstone Valley and the United States as a whole.
#    - **Location**: Spans RI and MA
#    - **Note**: The Visitor Center at Old Slater Mill is closed for the winter season.
#
# 2. **[Roger Williams National Memorial](https://www.nps.gov/rowi/index.htm)**
#    - **Description**: This memorial honors Roger Williams, founder of Providence in 1636, who advocated for religious freedom and was saved by the First Peoples after being banished by the English.
#    - **Location**: Providence, RI
#
# 3. **[Touro Synagogue National Historic Site](https://www.nps.gov/tosy/index.htm)**
#    - **Description**: Designated a National Historic Site in 1946, this synagogue remains active and is one of the most historically significant Jewish buildings in America. It welcomes over 30,000 visitors annually.
#    - **Location**: Newport, RI
#
# 4. **[Washington-Rochambeau Revolutionary Route National Historic Trail](https://www.nps.gov/waro/index.htm)**
#    - **Description**: This historical trail commemorates the route linked to the French-American cooperation during the American Revolutionary War.
#    - **Location**: Spans multiple states, including RI
#
# These sites offer a blend of historical significance and cultural insights into Rhode Island's past and its role in broader American history.

# %% [markdown]
# This isn't a terrible answer, but there is nothing about events here because the model didn't think to use the event tool.  If you are using a less powerful model, this sort of thing will happen even more often.  There isn't really a *general* solution for having models with limited effectiveness (and all models are limited -- some more than others).  However, if you have *specific* behaviors you want to optimize for, you can author structured workflows for those specific behaviors.  For example, imagine you are building this national parks assistant and your user research suggests that many users want to find upcoming events for parks, so you really want to do this very well even when the questions are not worded very precisely.  You can set up a flow like this:
#
# - First check to see if the question seems to be asking about upcoming events for parks
# - If so:
#   - Search for those parks
#   - Then search for the events for those parks and report on the events
# - Otherwise:
#   - Fall back to letting the agent decide what to do
#
# Note that this is exactly what the model *does* for the NPS_EXAMPLE_PROMPT, but doesn't quite do for the NPS_MORE_CHALLENGING_EXAMPLE_PROMPT.  Forcing the model to follow that path for this specific type of query can make it more accurate at this type of query at the cost of making it more complex and brittle.  Here is how to do that using the Responses API:

# %%
r1 = client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input=f'Here is a request: {NPS_MORE_CHALLENGING_EXAMPLE_PROMPT}.  Please respond ONLY with "upcoming events" or "something else".',
    instructions="You are a routing agent that decides whether a request is a question about upcoming events or something else."
)
print(NPS_MORE_CHALLENGING_EXAMPLE_PROMPT)
print(r1.output_text)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# What's up in Rhode Island?
# upcoming events

# %% [markdown]
# Since this returned "upcoming events" here, we'll continue with that branch of the flow:

# %%
r2 = client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input=f"Here is a request: {NPS_MORE_CHALLENGING_EXAMPLE_PROMPT}.  Please use the NPS MCP server to produce a list of national parks.",
    instructions="You are an agent that produces a list of national parks which will be used by a different agent to look up events at national parks.",
    # Notice that we are not using the previous response id for this turn.
    # The previous turn just routed us to this path so we don't need any other
    # information from that turn.
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "NPS",
            "allowed_tools": ["search_parks"],
            "authorization": NPS_ACCESS_TOKEN,
        }
    ]
)
print(r2.output_text)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# Here is a list of national parks in Rhode Island:
#
# 1. **Blackstone River Valley National Historical Park**
#    - Description: The Blackstone River powered America's entry into the Age of Industry. The success of Samuel Slater's cotton spinning mill in Pawtucket, RI touched off a chain reaction that changed how people worked and where they lived. Learn how this revolution transformed the landscape of the Blackstone Valley and the United States. The Visitor Center at Old Slater Mill is closed for the winter season.
#    - Website: [Blackstone River Valley National Historical Park](https://www.nps.gov/blrv/index.htm)
#    - Location: Rhode Island, Massachusetts
#
# 2. **Roger Williams National Memorial**
#    - Description: "I acknowledge that to molest any person, Jew or Gentile, for either professing doctrine, or practicing worship meerly religious or spiritual, is to persecute him, and such a person (whether his doctrine or practice be true or false) suffers persecution for conscience." -Roger Williams, 1644. Banished by the English and saved by the First Peoples, Roger Williams founded Providence here in 1636.
#    - Website: [Roger Williams National Memorial](https://www.nps.gov/rowi/index.htm)
#    - Location: Rhode Island
#
# 3. **Touro Synagogue National Historic Site**
#    - Description: Touro Synagogue, a building of exquisite beauty and design, steeped in history and ideals, and one of the most historically significant Jewish buildings in America, was designated a National Historic Site in 1946. Dedicated in 1763, it still serves an active congregation and greets over 30,000 visitors each year who come to see the magnificent interior and hear its remarkable story.
#    - Website: [Touro Synagogue National Historic Site](https://www.nps.gov/tosy/index.htm)
#    - Location: Rhode Island
#
# 4. **Washington-Rochambeau Revolutionary Route National Historic Trail**
#    - Description: “Of the happiness I have enjoyed in our private friendship. The remembrance of which will be one of the most pleasing Circumstances of my life.”– Comte de Rochambeau on his relationship with George Washington
#    - Website: [Washington-Rochambeau Revolutionary Route National Historic Trail](https://www.nps.gov/waro/index.htm)
#    - Location: Massachusetts, Rhode Island, Connecticut, New York, New Jersey, Pennsylvania, Delaware, Maryland, Virginia, District of Columbia
#
# These parks provide historical insights and recreational opportunities across Rhode Island, highlighting significant events and figures.

# %% [markdown]
# Next we could iterate through all the tool calls in r2 (they are included in the full structured object) and pull all the park IDs from that structured data.  However, if our model is powerful enough, we can just give the model the full context (using the previous response ID) and tell it to find all the parks:

# %%
r3 = client.responses.create(
    model=LLAMA_STACK_MODEL_ID,
    input=f"Here is a request: {NPS_MORE_CHALLENGING_EXAMPLE_PROMPT}.  Please use the NPS MCP server to look up events at the national parks in the previously provided list.",
    instructions="You are an agent that looks up events at national parks and reports the results to a human reader.",
    # Notice that we are using the previous response id from the previous turn
    # as the previous response id for this turn.  This allows the
    # new turn to use the result of the previous turn as input which is essential here
    # because we're now using that list to look up events.
    previous_response_id=r2.id,
    tools=[
        {
            "type": "mcp",
            "server_url": NPS_MCP_URL,
            "server_label": "NPS",
            "allowed_tools": ["get_park_events"],
            "authorization": NPS_ACCESS_TOKEN,
        }
    ],
)
print(r3.output_text)
# Out:
# INFO:httpx:HTTP Request: POST http://localhost:8321/v1/responses "HTTP/1.1 200 OK"
# Here are the upcoming events at national parks in Rhode Island:
#
# ### Blackstone River Valley National Historical Park
# 1. **Blackstone Canal Hike Series**
#    - Description: Join for hikes on Saturday mornings in January at 10:30 AM. Depart from various locations along the historic Blackstone Canal. All hikes are free and presented in partnership with MA DCR.
#    - Locations and Dates:
#      - **January 3**: Meet at the Kelly House Museum, 1075 Lower River Road, Lincoln, RI
#      - **January 10**: Meet at Blackstone River Greenway Parking Lot, Corner of Central Street and Hope Street, Millville, MA
#      - **January 17**: Meet at Trailhead at 9 Cross Street, Uxbridge, MA
#      - **January 24**: Meet at River Bend Farm Visitor Center, 287 Oak Street, Uxbridge, MA
#    - Note: Events may be canceled due to inclement weather. Check the [park’s website](https://www.nps.gov/blrv/index.htm) and Facebook page for updates.
#
# 2. **Revolutionary War Pension Files Transcription Event**
#    - Description: In celebration of the 250th anniversary of American independence, join to transcribe Revolutionary War Pension Files at the Upton Community Center on Wednesday, January 14, 2026, from 6-8 PM. Learn about the value of wartime pensions and hear service stories. Capacity is limited to 25 participants. Bring a laptop or tablet.
#    - Interested participants should email: [UptonMAHistoricalSociety@gmail.com](mailto:UptonMAHistoricalSociety@gmail.com)
#
# ### Roger Williams National Memorial
# - **Visitor Center Open**
#   - Description: Explore the life and legacy of Roger Williams with Park Rangers and volunteers. Watch a 5-minute film, read exhibits, browse the bookstore, and use the facilities.
#
# ### Touro Synagogue National Historic Site
# - No upcoming events found for this park.
#
# ### Washington-Rochambeau Revolutionary Route National Historic Trail
# - No upcoming events found for this park.
#
# Enjoy exploring these parks and their rich histories!

# %% [markdown]
# As you can see this multi-step flow is able to get to the correct response because it was coded to follow the correct steps.  In practice, it is often necessary to do this sort of thing when trying to make an agentic system reliable enough to deploy into a production environment.
#
# In the examples above, we just call the Responses API directly but there are a lot of other ways to do this sort of thing:
#
# - LangGraph provides a convenient framework for authoring and running multi-step workflows like this.  It provides a graph structure where the steps are nodes and the transitions between them are edges with well-defined contracts for what each step requires and produces.
# - You could also write your own graph data structures to do the same thing.
# - You could wrap the entire flow into a single object and call it "EventSearchOptimizedAgent" or something like that.
# - You could wrap each step onto a simple Agent object (like the ones shown in earlier sections of the notebook) and then chain them together the same way they are chained together using Responses above.
#
# These are all reasonable options and there are plenty of others too.  Chose an approach that fits well with the rest of your application.

# %% [markdown]
# ## Multi-process architectures
#
# The examples in all of the previous sections of this notebook assume that the agent creation, session creation, and turn creation are all taking place in the same process.  However, some users of the legacy Agents API might be having one process that creates agents (e.g., an agent management console) and another process that uses the agents (e.g., a chatbot app that invokes that process).  Assuming these processes have different life cycles and run on different kinds of machines, here are some examples of ideas for how to handle these cases:
#
# - If the agent creation logic is simple and static, then you can just move that agent creation logic into the application that uses the agent as in the examples above.  One downside of doing that is that you need to release a new version of the application that uses the agent every time the definition of the agent changes.  If that's not feasible for you, consider one of the other options.
# - You can have some sort of key-value storage mechanism contain a description of the agent (i.e., the instructions, list of tools).  The process that creates agents can write that configuration to the storage and the process that invokes the agent can read from it.
# - You can have the process that creates the agent deploy a container with that agent into a cluster and the process that invokes the agent call that container (which would then call Llama Stack via the Responses API).  This is a much heavier and more disruptive change than just putting agent configuration into a key-value store, but potentially much more powerful too since you can build complex agents with multiple phases that use different models under different circumstances, etc.
#
# There are many other possible architectures to explore too.
